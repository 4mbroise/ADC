# %%
import sys, time, json, re
from anytree import Node, RenderTree
from anytree.exporter import JsonExporter
from anytree import Node, RenderTree

sys.setrecursionlimit(100000)

# %%
def group_arguments(tableau):
    argGroup = tableau[0]
    i = 1

    while True:

        if i > len(tableau) - 1:
            return [argGroup]

        stance = re.search(r"(Con|Pro)(?::)", tableau[i])
        if stance == None:
            argGroup = argGroup + " " + tableau[i]
            i+=1
        else:
            return [argGroup] + group_arguments(tableau[i:])

# %%
def rawKialo2Json(input_file):
    with open(input_file, 'r') as fi:
        lines = []
        for line in fi:
            if line.startswith("Sources:"):
                break
            lines.append(line.strip())

        lines = [x for x in lines if x]

        # list containing each parsed comment
        result = []

        # we remove the first two lines of the text
        # as we don't need the header
        header = []
        for line in range(0, 4):
            header.append(lines.pop(0))

        subject = header[1]

        lines = group_arguments(lines)

        ##                                            ##
        ##                 REGEDITS                   ##
        ##                                            ##
        # iterate every row in the text file
        counter = 1
        for line in lines:

            # find the tree position the comment is in
            tree =  re.search(r"^(\d{1,}.)+", line)

            # find if the comment is Pro or Con
            stance = re.search(r"(Con|Pro)(?::)", line)

            # find the text of the comment
            content = re.search(r"((Con|Pro)(?::\s))(.*)", line)

            # define the hierarchy of the current comment
            # which is based on the tree structure

            parsed = re.findall(r"(\d{1,}(?=\.))+", tree.group())
            level = len(parsed)-1

            # make a dictionary with the single entry
            # and put it at the end of the list
            result.append({
                "Tree": tree.group(),
                "Level": level,
                "Stance": stance.group(1),
                "ToneInput": content.group(3),
                "node_id":subject.replace(" ","_")+"_"+str(counter)
            })

            counter+=1
        
        to_write = json.dumps(result, sort_keys=True, indent=4, separators=(',', ': '))

    trees = [x["Tree"] for x in result]
    trees = ['1.'] + trees

    resultAsDict = { x["Tree"]: x for x in result }

    id2Node = {}


    for idNode in trees:
        if idNode == '1.':
            id2Node[idNode] = Node(idNode, node_id=-1)
        else:
            parentId = idNode[:idNode[:-1].rfind(".")+1]
            id2Node[idNode] = Node(idNode,
                                    parent=id2Node[parentId],
                                    tree=resultAsDict[idNode]["Tree"], 
                                    level=resultAsDict[idNode]["Level"], 
                                    stance=resultAsDict[idNode]["Stance"], 
                                    toneInput=resultAsDict[idNode]["ToneInput"], 
                                    subject=subject,
                                    node_id=resultAsDict[idNode]["node_id"]
    )

    return id2Node

# %%
def argumentTree2argumentPairTree(node, domains):    
    pairs = []
    
    if len(node.children) == 0:
        return pairs
    elif node.children != None:
        for child in node.children:
            if node.name != "1.":
                pair = {
                    "topArgument"       :   node.toneInput,
                    "subArgument"       :   child.toneInput,
                    "subject"           :   child.subject,
                    "subArgumentLevel"  :   child.level,
                    "domain"            :   domains
                }
                if child.stance == "Con":
                    pair["isAttack"] = True
                    pair["isSupport"] = False
                else:
                    pair["isAttack"] = False
                    pair["isSupport"] = True
                pairs.append(pair)

            pairs += argumentTree2argumentPairTree(child, domains)
        
    return pairs
    return pairs

# %%
import pandas as pd

kialoUrlIds = pd.read_csv("../../rawData/kialo/kialo-url-ids.csv", index_col=0)
pairs = []

for i, x in kialoUrlIds.iterrows():
  try:
    d = x.tags
    kialoUrlId = x.kialoUrlId

    # print(x)

    t = rawKialo2Json("../../rawData/kialo/debates/"+ kialoUrlId +".txt")
    pairs = pairs + argumentTree2argumentPairTree(t['1.'], d)
  except:
    continue

# %%
pairs
# Out:
# [{'topArgument': 'Purity pledges lead to people having a poorer understanding of sexuality.',
#   'subArgument': 'Purity pledges lead to people not having a proper understanding of the potential consequences of sex.',
#   'subject': 'Are Purity Pledges Harmful?',
#   'subArgumentLevel': 2,
#   'domain': "['Purity', 'Sex', 'Virginity', 'Feminism', 'Women']",
#   'isAttack': False,
#   'isSupport': True},
#  {'topArgument': 'Purity pledges lead to people not having a proper understanding of the potential consequences of sex.',
#   'subArgument': 'Purity pledges are a facet of abstinence-only sex education [1]. These programs disseminate false information regarding sex.',
#   'subject': 'Are Purity Pledges Harmful?',
#   'subArgumentLevel': 3,
#   'domain': "['Purity', 'Sex', 'Virginity', 'Feminism', 'Women']",
#   'isAttack': False,
#   'isSupport': True},
#  {'topArgument': 'Purity pledges are a facet of abstinence-only sex education [1]. These programs disseminate false information regarding sex.',
#   'subArgument': 'Abstinence programmes are likely to lead to people engaging in unsafe sex.',
#   'subject': 'Are Purity Pledges Harmful?',
#   'subArgumentLevel': 4,
#   'domain': "['Purity', 'Sex', 'Virginity', 'Feminism', 'Women']",
#   'isAttack': False,
#   'isSupport': True},
#  {'topArgument': 'Abstinence programmes are likely to lead to people engaging in unsafe sex.',
#   'subArgument': 'Pledgers often believe contraceptives are unreliable. Some abstinence groups tell their students condoms have a 30% fail rate (Paul, 4 [2]).',
#   'subject': 'Are Purity Pledges Harmful?',
#   'subArgumentLevel': 5,
#   'domain': "['Purity', 'Sex', 'Virginity', 'Feminism', 'Women']",
#   'isAttack': False,
#   'isSupport': True},
#  {'topArgument': 'Abstinence programmes are likely to lead to people engaging in unsafe sex.',
#   'subArgument': 'Abstinence programmes push against [3] increasing access to contraceptives. They have even called the Gardasil vaccine the “whore drug,” as they believe it gives young women the idea that they have promiscuous sex without the repercussions of HPV and ovarian cancer (Paul, 6 [4]).',
#   'subject': 'Are Purity Pledges Harmful?',
#   'subArgumentLevel': 5,
#   'domain': "['Purity', 'Sex', 'Virginity', 'Feminism', 'Women']",
#   'isAttack': False,
#   'isSupport': True},
#  {'topArgument': 'Abstinence programmes are likely to lead to people engaging in unsafe sex.',
#   'subArgument': 'A study found that pledging does not appear to affect sexual safety among pledgers who fail to remain abstinent (p. 8 [5]).',
#   'subject': 'Are Purity Pledges Harmful?',
#   'subArgumentLevel': 5,
#   'domain': "['Purity', 'Sex', 'Virginity', 'Feminism', 'Women']",
#   'isAttack': True,
#   'isSupport': False},
#  {'topArgument': 'Abstinence programmes are likely to lead to people engaging in unsafe sex.',
#   'subArgument': 'There is no guarantee that a pledger will be part of an abstinence programme.',
#   'subject': 'Are Purity Pledges Harmful?',
#   'subArgumentLevel': 5,
#   'domain': "['Purity', 'Sex', 'Virginity', 'Feminism', 'Women']",
#   'isAttack': True,
#   'isSupport': False},
#  {'topArgument': 'Purity pledges are a facet of abstinence-only sex education [1]. These programs disseminate false information regarding sex.',
#   'subArgument': 'A report found that 80 percent of the most popular curricula used by federally funded, abstinence-only education programs distorted information and blurred the line between science and religion (p. i [6]).',
#   'subject': 'Are Purity Pledges Harmful?',
#   'subArgumentLevel': 4,
#   'domain': "['Purity', 'Sex', 'Virginity', 'Feminism', 'Women']",
#   'isAttack': False,
#   'isSupport': True},
#  {'topArgument': 'A report found that 80 percent of the most popular curricula used by federally funded, abstinence-only education programs distorted information and blurred the line between science and religion (p. i [6]).',
#   'subArgument': 'Abstinence programs generally promote the idea that contraceptives are ineffective and even harmful [7].',
#   'subject': 'Are Purity Pledges Harmful?',
#   'subArgumentLevel': 5,
#   'domain': "['Purity', 'Sex', 'Virginity', 'Feminism', 'Women']",
#   'isAttack': False,
#   'isSupport': True},
#  {'topArgument': 'Abstinence programs generally promote the idea that contraceptives are ineffective and even harmful [7].',
#   'subArgument': '-> See 1.1.1.1.1.1.',
#   'subject': 'Are Purity Pledges Harmful?',
#   'subArgumentLevel': 6,
#   'domain': "['Purity', 'Sex', 'Virginity', 'Feminism', 'Women']",
#   'isAttack': False,
#   'isSupport': True},
#  {'topArgument': 'Abstinence programs generally promote the idea that contraceptives are ineffective and even harmful [7].',
#   'subArgument': 'These programs claim birth control causes cancer (p. 4 [8]).',
#   'subject': 'Are Purity Pledges Harmful?',
#   'subArgumentLevel': 6,
#   'domain': "['Purity', 'Sex', 'Virginity', 'Feminism', 'Women']",
#   'isAttack': False,
#   'isSupport': True},
#  {'topArgument': 'These programs claim birth control causes cancer (p. 4 [8]).',
#   'subArgument': 'Some condoms leach nitrosamine [9], a chemical thought to be carcinogenic and which has not been tested against the mucus membranes of the mouth and genitals.',
#   'subject': 'Are Purity Pledges Harmful?',
#   'subArgumentLevel': 7,
#   'domain': "['Purity', 'Sex', 'Virginity', 'Feminism', 'Women']",
#   'isAttack': True,
#   'isSupport': False},
#  {'topArgument': 'Some condoms leach nitrosamine [9], a chemical thought to be carcinogenic and which has not been tested against the mucus membranes of the mouth and genitals.',
#   'subArgument': 'The risk of tumors from nitrosamines in condoms is exceedingly low. In fact, the detectable level of nitrosamines in condoms is lower [10] than those found in food, water, and other consumer goods.',
#   'subject': 'Are Purity Pledges Harmful?',
#   'subArgumentLevel': 8,
#   'domain': "['Purity', 'Sex', 'Virginity', 'Feminism', 'Women']",
#   'isAttack': True,
#   'isSupport': False},
#  {'topArgument': 'Abstinence programs generally promote the idea that contraceptives are ineffective and even harmful [7].',
#   'subArgument': 'None of the curricula provides information on how to select a birth control method and use it effectively (Waxman, 11 [11].)',
#   'subject': 'Are Purity Pledges Harmful?',
#   'subArgumentLevel': 6,
#   'domain': "['Purity', 'Sex', 'Virginity', 'Feminism', 'Women']",
#   'isAttack': False,
#   'isSupport': True},
#  {'topArgument': 'Abstinence programs generally promote the idea that contraceptives are ineffective and even harmful [7].',
#   'subArgument': 'While birth control is often safe, it is entirely possible for it to be harmful [12].',
#   'subject': 'Are Purity Pledges Harmful?',
#   'subArgumentLevel': 6,
#   'domain': "['Purity', 'Sex', 'Virginity', 'Feminism', 'Women']",
#   'isAttack': True,
#   'isSupport': False},
#  {'topArgument': 'Abstinence programs generally promote the idea that contraceptives are ineffective and even harmful [7].',
#   'subArgument': 'Many common things can render contraception ineffective [13].',
#   'subject': 'Are Purity Pledges Harmful?',
#   'subArgumentLevel': 6,
#   'domain': "['Purity', 'Sex', 'Virginity', 'Feminism', 'Women']",
#   'isAttack': True,
#   'isSupport': False},
#  {'topArgument': 'A report found that 80 percent of the most popular curricula used by federally funded, abstinence-only education programs distorted information and blurred the line between science and religion (p. i [6]).',
#   'subArgument': 'These programs misrepresent the risks of abortion.',
#   'subject': 'Are Purity Pledges Harmful?',
#   'subArgumentLevel': 5,
#   'domain': "['Purity', 'Sex', 'Virginity', 'Feminism', 'Women']",
#   'isAttack': False,
#   'isSupport': True},
#  {'topArgument': 'These programs misrepresent the risks of abortion.',
#   'subArgument': 'One curriculum states that 5% to 10% of women who have legal abortions will become sterile (Waxman, i [14])',
#   'subject': 'Are Purity Pledges Harmful?',
#   'subArgumentLevel': 6,
#   'domain': "['Purity', 'Sex', 'Virginity', 'Feminism', 'Women']",
#   'isAttack': False,
#   'isSupport': True},
#  {'topArgument': 'One curriculum states that 5% to 10% of women who have legal abortions will become sterile (Waxman, i [14])',
#   'subArgument': 'Abortions do lead to a small increase in fertility and pregnancy complications [15]',
#   'subject': 'Are Purity Pledges Harmful?',
#   'subArgumentLevel': 7,
#   'domain': "['Purity', 'Sex', 'Virginity', 'Feminism', 'Women']",
#   'isAttack': True,
#   'isSupport': False},
#  {'topArgument': 'Abortions do lead to a small increase in fertility and pregnancy complications [15]',
#   'subArgument': 'According to the source, the risk of fertility and pregnancy complications in abortions is rare. A rare side-effect [16] has an incidence of less than 0.01% and is thus significantly less than the statistic cited (5-10%) by the curriculum for the risk of sterility.',
#   'subject': 'Are Purity Pledges Harmful?',
#   'subArgumentLevel': 8,
#   'domain': "['Purity', 'Sex', 'Virginity', 'Feminism', 'Women']",
#   'isAttack': True,
#   'isSupport': False},
#  {'topArgument': 'These programs misrepresent the risks of abortion.',
#   'subArgument': 'A curriculum states that mental retardation (resulting from premature birth) is increased following the abortion of the first pregnancy. Obstetrics textbooks teach that vacuum aspiration, the method used in most abortions in the United States, does not result in an increase in such risks (Waxman, 13 [17])',
#   'subject': 'Are Purity Pledges Harmful?',
#   'subArgumentLevel': 6,
#   'domain': "['Purity', 'Sex', 'Virginity', 'Feminism', 'Women']",
#   'isAttack': False,
#   'isSupport': True},
#  {'topArgument': 'A curriculum states that mental retardation (resulting from premature birth) is increased following the abortion of the first pregnancy. Obstetrics textbooks teach that vacuum aspiration, the method used in most abortions in the United States, does not result in an increase in such risks (Waxman, 13 [17])',
#   'subArgument': 'While vacuum aspiration of the first pregnancy was not found to have lasting effects, multiple procedures [18] do have an effect on subsequent pregnancies in half the studies.',
#   'subject': 'Are Purity Pledges Harmful?',
#   'subArgumentLevel': 7,
#   'domain': "['Purity', 'Sex', 'Virginity', 'Feminism', 'Women']",
#   'isAttack': True,
#   'isSupport': False},
#  {'topArgument': 'A report found that 80 percent of the most popular curricula used by federally funded, abstinence-only education programs distorted information and blurred the line between science and religion (p. i [6]).',
#   'subArgument': 'Abstinence-only curricula contain scientific errors.',
#   'subject': 'Are Purity Pledges Harmful?',
#   'subArgumentLevel': 5,
#   'domain': "['Purity', 'Sex', 'Virginity', 'Feminism', 'Women']",
#   'isAttack': False,
#   'isSupport': True},
#  {'topArgument': 'Abstinence-only curricula contain scientific errors.',
#   'subArgument': 'Within an abstinence program, a 43-day-old fetus was referred to as a “thinking person (Waxman, ii [19]).',
#   'subject': 'Are Purity Pledges Harmful?',
#   'subArgumentLevel': 6,
#   'domain': "['Purity', 'Sex', 'Virginity', 'Feminism', 'Women']",
#   'isAttack': False,
#   'isSupport': True},
#  {'topArgument': 'Within an abstinence program, a 43-day-old fetus was referred to as a “thinking person (Waxman, ii [19]).',
#   'subArgument': 'Electrical activity in the developing fetus\' brain [20] is found at 43 days. As there is no scientific definition of "thought", a "thinking person" could be defined as any human tissue with its own brain activity.',
#   'subject': 'Are Purity Pledges Harmful?',
#   'subArgumentLevel': 7,
#   'domain': "['Purity', 'Sex', 'Virginity', 'Feminism', 'Women']",
#   'isAttack': True,
#   'isSupport': False},
#  {'topArgument': 'Abstinence-only curricula contain scientific errors.',
#   'subArgument': 'There is no necessary reason that all abstinence-only curricula would contain errors.',
#   'subject': 'Are Purity Pledges Harmful?',
#   'subArgumentLevel': 6,
#   'domain': "['Purity', 'Sex', 'Virginity', 'Feminism', 'Women']",
#   'isAttack': True,
#   'isSupport': False},
#  {'topArgument': 'There is no necessary reason that all abstinence-only curricula would contain errors.',
#   'subArgument': 'Abstinence is a moral position, not a factual one. It is possible to correctly portray the facts of sexual health and education and still argue in favour of abstinence.',
#   'subject': 'Are Purity Pledges Harmful?',
#   'subArgumentLevel': 7,
#   'domain': "['Purity', 'Sex', 'Virginity', 'Feminism', 'Women']",
#   'isAttack': False,
#   'isSupport': True},
#  {'topArgument': 'Purity pledges are a facet of abstinence-only sex education [1]. These programs disseminate false information regarding sex.',
#   'subArgument': 'In the US, teenage pregnancies and STDs were on the rise again [21] after the push by President Bush for abstinence-only sex education programs in 2007.',
#   'subject': 'Are Purity Pledges Harmful?',
#   'subArgumentLevel': 4,
#   'domain': "['Purity', 'Sex', 'Virginity', 'Feminism', 'Women']",
#   'isAttack': False,
#   'isSupport': True},
#  {'topArgument': 'In the US, teenage pregnancies and STDs were on the rise again [21] after the push by President Bush for abstinence-only sex education programs in 2007.',
#   'subArgument': 'A study by the National Campaign to Prevent Teen and Unplanned Pregnancy, in 2007, showed that programs that combine abstinence and contraception were mostly ineffective (p. 1 [22]).',
#   'subject': 'Are Purity Pledges Harmful?',
#   'subArgumentLevel': 5,
#   'domain': "['Purity', 'Sex', 'Virginity', 'Feminism', 'Women']",
#   'isAttack': False,
#   'isSupport': True},
#  {'topArgument': 'A study by the National Campaign to Prevent Teen and Unplanned Pregnancy, in 2007, showed that programs that combine abstinence and contraception were mostly ineffective (p. 1 [22]).',
#   'subArgument': "Another study found that abstinence-only educational programmes had no beneficial impact [23] on young people's sexual behaviour.",
#   'subject': 'Are Purity Pledges Harmful?',
#   'subArgumentLevel': 6,
#   'domain': "['Purity', 'Sex', 'Virginity', 'Feminism', 'Women']",
#   'isAttack': False,
#   'isSupport': True},
#  {'topArgument': 'A study by the National Campaign to Prevent Teen and Unplanned Pregnancy, in 2007, showed that programs that combine abstinence and contraception were mostly ineffective (p. 1 [22]).',
#   'subArgument': 'Another 2007 study [24], by the Mathematica Policy Research, showed students in abstinence-only programs were not more likely to abstain from sex, delay having sex, or have fewer partners than students who received no sex education at all.',
#   'subject': 'Are Purity Pledges Harmful?',
#   'subArgumentLevel': 6,
#   'domain': "['Purity', 'Sex', 'Virginity', 'Feminism', 'Women']",
#   'isAttack': False,
#   'isSupport': True},
#  {'topArgument': 'In the US, teenage pregnancies and STDs were on the rise again [21] after the push by President Bush for abstinence-only sex education programs in 2007.',
#   'subArgument': 'These harmful effects have subsided since the Obama administration, in 2010, started funding and implementing [25] a comprehensive teen pregnancy prevention program that focuses on boosting academic achievement, extracurricular activities, and smarter life decisions rather than the failed abstinence-only sex education programs.',
#   'subject': 'Are Purity Pledges Harmful?',
#   'subArgumentLevel': 5,
#   'domain': "['Purity', 'Sex', 'Virginity', 'Feminism', 'Women']",
#   'isAttack': True,
#   'isSupport': False},
#  {'topArgument': 'These harmful effects have subsided since the Obama administration, in 2010, started funding and implementing [25] a comprehensive teen pregnancy prevention program that focuses on boosting academic achievement, extracurricular activities, and smarter life decisions rather than the failed abstinence-only sex education programs.',
#   'subArgument': 'The US Department of Health and Human Services announced [26] that $155 million in teen pregnancy prevention grants were being awarded to states, non-profit organisations, school districts, universities and others.',
#   'subject': 'Are Purity Pledges Harmful?',
#   'subArgumentLevel': 6,
#   'domain': "['Purity', 'Sex', 'Virginity', 'Feminism', 'Women']",
#   'isAttack': False,
#   'isSupport': True},
#  {'topArgument': 'Purity pledges are a facet of abstinence-only sex education [1]. These programs disseminate false information regarding sex.',
#   'subArgument': 'Purity pledges should not be considered responsible for the misinformation propagated in abstinence-only sex education programmes.',
#   'subject': 'Are Purity Pledges Harmful?',
#   'subArgumentLevel': 4,
#   'domain': "['Purity', 'Sex', 'Virginity', 'Feminism', 'Women']",
#   'isAttack': True,
#   'isSupport': False},
#  {'topArgument': 'Purity pledges are a facet of abstinence-only sex education [1]. These programs disseminate false information regarding sex.',
#   'subArgument': 'The factual inaccuracies peddled by these programs can be removed from their curricula.',
#   'subject': 'Are Purity Pledges Harmful?',
#   'subArgumentLevel': 4,
#   'domain': "['Purity', 'Sex', 'Virginity', 'Feminism', 'Women']",
#   'isAttack': True,
#   'isSupport': False},
#  {'topArgument': 'The factual inaccuracies peddled by these programs can be removed from their curricula.',
#   'subArgument': 'It is possible to teach an abstinence-only programme without including misinformation about sex.',
#   'subject': 'Are Purity Pledges Harmful?',
#   'subArgumentLevel': 5,
#   'domain': "['Purity', 'Sex', 'Virginity', 'Feminism', 'Women']",
#   'isAttack': False,
#   'isSupport': True},
#  {'topArgument': 'The factual inaccuracies peddled by these programs can be removed from their curricula.',
#   'subArgument': 'By definition, abstinence programs [27] are limited to warning people against having premarital sex at all. Fitting in information about how to have safe sex will never be easy or natural in such a program.',
#   'subject': 'Are Purity Pledges Harmful?',
#   'subArgumentLevel': 5,
#   'domain': "['Purity', 'Sex', 'Virginity', 'Feminism', 'Women']",
#   'isAttack': True,
#   'isSupport': False},
#  {'topArgument': 'Purity pledges lead to people not having a proper understanding of the potential consequences of sex.',
#   'subArgument': 'A pledge alone is not a bar on education.',
#   'subject': 'Are Purity Pledges Harmful?',
#   'subArgumentLevel': 3,
#   'domain': "['Purity', 'Sex', 'Virginity', 'Feminism', 'Women']",
#   'isAttack': True,
#   'isSupport': False},
#  {'topArgument': 'A pledge alone is not a bar on education.',
#   'subArgument': 'Individuals taking this pledge are encouraged to keep their minds clear of sexual thoughts [28], and by doing so they are more likely to ignore many important questions they may have about their body and other sexual functions.',
#   'subject': 'Are Purity Pledges Harmful?',
#   'subArgumentLevel': 4,
#   'domain': "['Purity', 'Sex', 'Virginity', 'Feminism', 'Women']",
#   'isAttack': True,
#   'isSupport': False},
#  {'topArgument': 'Individuals taking this pledge are encouraged to keep their minds clear of sexual thoughts [28], and by doing so they are more likely to ignore many important questions they may have about their body and other sexual functions.',
#   'subArgument': 'Purity pledges are particularly harmful [29] for young people questioning and trying to understand their sexuality.',
#   'subject': 'Are Purity Pledges Harmful?',
#   'subArgumentLevel': 5,
#   'domain': "['Purity', 'Sex', 'Virginity', 'Feminism', 'Women']",
#   'isAttack': False,
#   'isSupport': True},
#  {'topArgument': 'Purity pledges are particularly harmful [29] for young people questioning and trying to understand their sexuality.',
#   'subArgument': 'When all sexual actions are considered a sin and abstinence is seen as the only legitimate behaviour by your family and community, young people have no one to turn to with questions about their sexuality.',
#   'subject': 'Are Purity Pledges Harmful?',
#   'subArgumentLevel': 6,
#   'domain': "['Purity', 'Sex', 'Virginity', 'Feminism', 'Women']",
#   'isAttack': False,
#   'isSupport': True},
#  {'topArgument': 'A pledge alone is not a bar on education.',
#   'subArgument': 'Being a pledger does not preclude someone from taking sexual education classes.',
#   'subject': 'Are Purity Pledges Harmful?',
#   'subArgumentLevel': 4,
#   'domain': "['Purity', 'Sex', 'Virginity', 'Feminism', 'Women']",
#   'isAttack': False,
#   'isSupport': True},
#  {'topArgument': 'Being a pledger does not preclude someone from taking sexual education classes.',
#   'subArgument': 'In many states in the USA, sexual education classes are compulsory [30].',
#   'subject': 'Are Purity Pledges Harmful?',
#   'subArgumentLevel': 5,
#   'domain': "['Purity', 'Sex', 'Virginity', 'Feminism', 'Women']",
#   'isAttack': False,
#   'isSupport': True},
#  {'topArgument': 'Purity pledges lead to people not having a proper understanding of the potential consequences of sex.',
#   'subArgument': "Other groups of people who don't engage in sex (e.g. asexual people) can still have an understanding of sex.",
#   'subject': 'Are Purity Pledges Harmful?',
#   'subArgumentLevel': 3,
#   'domain': "['Purity', 'Sex', 'Virginity', 'Feminism', 'Women']",
#   'isAttack': False,
#   'isSupport': True},
#  {'topArgument': "Other groups of people who don't engage in sex (e.g. asexual people) can still have an understanding of sex.",
#   'subArgument': 'It is less likely that asexual people will bother to learn about STDs, pregnancies, or other consequences of sex, as they have sex less often than the general population.',
#   'subject': 'Are Purity Pledges Harmful?',
#   'subArgumentLevel': 4,
#   'domain': "['Purity', 'Sex', 'Virginity', 'Feminism', 'Women']",
#   'isAttack': True,
#   'isSupport': False},
#  {'topArgument': 'Purity pledges lead to people not having a proper understanding of the potential consequences of sex.',
#   'subArgument': 'Purity pledges should not carry the burden of having to educate people on sex - this is the role of a sexual education class.',
#   'subject': 'Are Purity Pledges Harmful?',
#   'subArgumentLevel': 3,
#   'domain': "['Purity', 'Sex', 'Virginity', 'Feminism', 'Women']",
#   'isAttack': True,
#   'isSupport': False},
#  {'topArgument': 'Purity pledges should not carry the burden of having to educate people on sex - this is the role of a sexual education class.',
#   'subArgument': 'However, the culture of abstinence promoted by purity pledges could potentially interfere with the teachings of a sexual education class.',
#   'subject': 'Are Purity Pledges Harmful?',
#   'subArgumentLevel': 4,
#   'domain': "['Purity', 'Sex', 'Virginity', 'Feminism', 'Women']",
#   'isAttack': True,
#   'isSupport': False},
#  {'topArgument': 'Purity pledges should not carry the burden of having to educate people on sex - this is the role of a sexual education class.',
#   'subArgument': 'Purity pledges are an informal cultural tradition, and should not be considered to carry meaningful educative functions.',
#   'subject': 'Are Purity Pledges Harmful?',
#   'subArgumentLevel': 4,
#   'domain': "['Purity', 'Sex', 'Virginity', 'Feminism', 'Women']",
#   'isAttack': False,
#   'isSupport': True},
#  {'topArgument': 'Purity pledges lead to people not having a proper understanding of the potential consequences of sex.',
#   'subArgument': 'It is not important for people to understand the consequences of sex during the period that they intend to be abstinent. They should educate themselves on sex when they intend to make it a part of their life.',
#   'subject': 'Are Purity Pledges Harmful?',
#   'subArgumentLevel': 3,
#   'domain': "['Purity', 'Sex', 'Virginity', 'Feminism', 'Women']",
#   'isAttack': True,
#   'isSupport': False},
#  {'topArgument': 'Purity pledges lead to people having a poorer understanding of sexuality.',
#   'subArgument': 'Purity pledges lead to women entering the sexual phase of their lives completely unprepared (p. 8 [31]). This leaves them very vulnerable to being used, manipulated, and abused.',
#   'subject': 'Are Purity Pledges Harmful?',
#   'subArgumentLevel': 2,
#   'domain': "['Purity', 'Sex', 'Virginity', 'Feminism', 'Women']",
#   'isAttack': False,
#   'isSupport': True},
#  {'topArgument': 'Purity pledges lead to women entering the sexual phase of their lives completely unprepared (p. 8 [31]). This leaves them very vulnerable to being used, manipulated, and abused.',
#   'subArgument': 'Purity pledges, like other religious vows of celibacy [32], do not require [33] the pledger to be a virgin.',
#   'subject': 'Are Purity Pledges Harmful?',
#   'subArgumentLevel': 3,
#   'domain': "['Purity', 'Sex', 'Virginity', 'Feminism', 'Women']",
#   'isAttack': True,
#   'isSupport': False},
#  {'topArgument': 'Purity pledges lead to women entering the sexual phase of their lives completely unprepared (p. 8 [31]). This leaves them very vulnerable to being used, manipulated, and abused.',
#   'subArgument': 'A lack of discussion around consent in purity culture can leave pledgers unable to distinguish [34] between consensual and non-consensual interactions.',
#   'subject': 'Are Purity Pledges Harmful?',
#   'subArgumentLevel': 3,
#   'domain': "['Purity', 'Sex', 'Virginity', 'Feminism', 'Women']",
#   'isAttack': False,
#   'isSupport': True},
#  {'topArgument': 'A lack of discussion around consent in purity culture can leave pledgers unable to distinguish [34] between consensual and non-consensual interactions.',
#   'subArgument': "When pledgers are told that women must behave and dress in such a way so as to control men's desires, and then a non-consensual interaction takes place, the blame [35] is laid on the woman for not preventing it [36].",
#   'subject': 'Are Purity Pledges Harmful?',
#   'subArgumentLevel': 4,
#   'domain': "['Purity', 'Sex', 'Virginity', 'Feminism', 'Women']",
#   'isAttack': False,
#   'isSupport': True},
#  {'topArgument': "When pledgers are told that women must behave and dress in such a way so as to control men's desires, and then a non-consensual interaction takes place, the blame [35] is laid on the woman for not preventing it [36].",
#   'subArgument': 'Many purity culture teachings hold women directly responsible [37] for managing the sexual behaviour of the men around them.',
#   'subject': 'Are Purity Pledges Harmful?',
#   'subArgumentLevel': 5,
#   'domain': "['Purity', 'Sex', 'Virginity', 'Feminism', 'Women']",
#   'isAttack': False,
#   'isSupport': True},
#  {'topArgument': 'Many purity culture teachings hold women directly responsible [37] for managing the sexual behaviour of the men around them.',
#   'subArgument': 'Women are told to dress and behave modestly [38] so as not to tempt men.',
#   'subject': 'Are Purity Pledges Harmful?',
#   'subArgumentLevel': 6,
#   'domain': "['Purity', 'Sex', 'Virginity', 'Feminism', 'Women']",
#   'isAttack': False,
#   'isSupport': True},
#  {'topArgument': 'Many purity culture teachings hold women directly responsible [37] for managing the sexual behaviour of the men around them.',
#   'subArgument': 'Some Evangelicals preach [39] that men are more likely to be led astray because of "their hormones and their nature", and so the women around them are "responsible for their own purity and for helping young men remain pure".',
#   'subject': 'Are Purity Pledges Harmful?',
#   'subArgumentLevel': 6,
#   'domain': "['Purity', 'Sex', 'Virginity', 'Feminism', 'Women']",
#   'isAttack': False,
#   'isSupport': True},
#  {'topArgument': 'Some Evangelicals preach [39] that men are more likely to be led astray because of "their hormones and their nature", and so the women around them are "responsible for their own purity and for helping young men remain pure".',
#   'subArgument': 'This is arguably an accurate assessment of average teenage behavior [40], regardless of the ideological motivations behind it.',
#   'subject': 'Are Purity Pledges Harmful?',
#   'subArgumentLevel': 7,
#   'domain': "['Purity', 'Sex', 'Virginity', 'Feminism', 'Women']",
#   'isAttack': True,
#   'isSupport': False},
#  {'topArgument': 'Many purity culture teachings hold women directly responsible [37] for managing the sexual behaviour of the men around them.',
#   'subArgument': 'Pledges are taken by both men and women, so the notion that the burden of chastity is exclusively upon women is a misrepresentation of how pledgers themselves understand abstinence.',
#   'subject': 'Are Purity Pledges Harmful?',
#   'subArgumentLevel': 6,
#   'domain': "['Purity', 'Sex', 'Virginity', 'Feminism', 'Women']",
#   'isAttack': True,
#   'isSupport': False},
#  {'topArgument': "When pledgers are told that women must behave and dress in such a way so as to control men's desires, and then a non-consensual interaction takes place, the blame [35] is laid on the woman for not preventing it [36].",
#   'subArgument': 'Purity culture adds an extra layer of shame [41] for victims of sexual assault.',
#   'subject': 'Are Purity Pledges Harmful?',
#   'subArgumentLevel': 5,
#   'domain': "['Purity', 'Sex', 'Virginity', 'Feminism', 'Women']",
#   'isAttack': False,
#   'isSupport': True},
#  {'topArgument': "When pledgers are told that women must behave and dress in such a way so as to control men's desires, and then a non-consensual interaction takes place, the blame [35] is laid on the woman for not preventing it [36].",
#   'subArgument': 'Purity pledges encourage women to adopt the worldview that women are distinct and essentially different from men and that sexuality is in itself dangerous, resulting in the construction of sexual violence as “giving in” to temptation (Fahs, 117 [42])',
#   'subject': 'Are Purity Pledges Harmful?',
#   'subArgumentLevel': 5,
#   'domain': "['Purity', 'Sex', 'Virginity', 'Feminism', 'Women']",
#   'isAttack': False,
#   'isSupport': True},
#  {'topArgument': "When pledgers are told that women must behave and dress in such a way so as to control men's desires, and then a non-consensual interaction takes place, the blame [35] is laid on the woman for not preventing it [36].",
#   'subArgument': 'Rape is framed as boys "losing control" of their natural instincts, as opposed to committing a crime (Fahs, 121 [43]).',
#   'subject': 'Are Purity Pledges Harmful?',
#   'subArgumentLevel': 5,
#   'domain': "['Purity', 'Sex', 'Virginity', 'Feminism', 'Women']",
#   'isAttack': False,
#   'isSupport': True},
#  {'topArgument': "When pledgers are told that women must behave and dress in such a way so as to control men's desires, and then a non-consensual interaction takes place, the blame [35] is laid on the woman for not preventing it [36].",
#   'subArgument': "However, if a woman shows that she dressed and behaved 'modestly', it would prove impossible to pin the blame for any non-consensual interactions on her.",
#   'subject': 'Are Purity Pledges Harmful?',
#   'subArgumentLevel': 5,
#   'domain': "['Purity', 'Sex', 'Virginity', 'Feminism', 'Women']",
#   'isAttack': True,
#   'isSupport': False},
#  {'topArgument': "When pledgers are told that women must behave and dress in such a way so as to control men's desires, and then a non-consensual interaction takes place, the blame [35] is laid on the woman for not preventing it [36].",
#   'subArgument': 'The fact that women are held more accountable for sexual interaction does not entirely preclude men from any accountability - it is entirely possible that violent sexual harassment would still be blamed on the male perpetrators.',
#   'subject': 'Are Purity Pledges Harmful?',
#   'subArgumentLevel': 5,
#   'domain': "['Purity', 'Sex', 'Virginity', 'Feminism', 'Women']",
#   'isAttack': True,
#   'isSupport': False},
#  {'topArgument': 'Purity pledges lead to women entering the sexual phase of their lives completely unprepared (p. 8 [31]). This leaves them very vulnerable to being used, manipulated, and abused.',
#   'subArgument': "A particular problem for pledgers is that of 'cultural lag' [44] - people update their values faster than they update their actions to correspond to those values. This results in large numbers of pledgers deciding to have premarital sex, but not deciding to use birth control or condoms.",
#   'subject': 'Are Purity Pledges Harmful?',
#   'subArgumentLevel': 3,
#   'domain': "['Purity', 'Sex', 'Virginity', 'Feminism', 'Women']",
#   'isAttack': False,
#   'isSupport': True},
#  {'topArgument': "A particular problem for pledgers is that of 'cultural lag' [44] - people update their values faster than they update their actions to correspond to those values. This results in large numbers of pledgers deciding to have premarital sex, but not deciding to use birth control or condoms.",
#   'subArgument': 'This is particularly relevant since pledging is often accompanied by anti birth control [45] rhetoric.',
#   'subject': 'Are Purity Pledges Harmful?',
#   'subArgumentLevel': 4,
#   'domain': "['Purity', 'Sex', 'Virginity', 'Feminism', 'Women']",
#   'isAttack': False,
#   'isSupport': True},
#  {'topArgument': 'Purity pledges lead to women entering the sexual phase of their lives completely unprepared (p. 8 [31]). This leaves them very vulnerable to being used, manipulated, and abused.',
#   'subArgument': 'Women who do not have experience with sex and relationships may be more easily manipulated and lied to by predatory men.',
#   'subject': 'Are Purity Pledges Harmful?',
#   'subArgumentLevel': 3,
#   'domain': "['Purity', 'Sex', 'Virginity', 'Feminism', 'Women']",
#   'isAttack': False,
#   'isSupport': True},
#  {'topArgument': 'Women who do not have experience with sex and relationships may be more easily manipulated and lied to by predatory men.',
#   'subArgument': 'Manipulative men have a tendency to seek relationships [46] with women who have less romantic experience.',
#   'subject': 'Are Purity Pledges Harmful?',
#   'subArgumentLevel': 4,
#   'domain': "['Purity', 'Sex', 'Virginity', 'Feminism', 'Women']",
#   'isAttack': False,
#   'isSupport': True},
#  {'topArgument': 'Women who do not have experience with sex and relationships may be more easily manipulated and lied to by predatory men.',
#   'subArgument': "Manipulative men may make the early stages of a new relationship feel like 'a fairy tale [47]' - it can be difficult for women inexperienced with dating to identify their inauthenticity in the face of this tactic.",
#   'subject': 'Are Purity Pledges Harmful?',
#   'subArgumentLevel': 4,
#   'domain': "['Purity', 'Sex', 'Virginity', 'Feminism', 'Women']",
#   'isAttack': False,
#   'isSupport': True},
#  {'topArgument': "Manipulative men may make the early stages of a new relationship feel like 'a fairy tale [47]' - it can be difficult for women inexperienced with dating to identify their inauthenticity in the face of this tactic.",
#   'subArgument': "A woman who has not had much exposure to manipulative men in the past may be more easily swayed by tactics such as 'love bombing' [48].",
#   'subject': 'Are Purity Pledges Harmful?',
#   'subArgumentLevel': 5,
#   'domain': "['Purity', 'Sex', 'Virginity', 'Feminism', 'Women']",
#   'isAttack': False,
#   'isSupport': True},
#  {'topArgument': 'Women who do not have experience with sex and relationships may be more easily manipulated and lied to by predatory men.',
#   'subArgument': 'Having experience with sex and relationships does not make women impervious to the advances of manipulative men.',
#   'subject': 'Are Purity Pledges Harmful?',
#   'subArgumentLevel': 4,
#   'domain': "['Purity', 'Sex', 'Virginity', 'Feminism', 'Women']",
#   'isAttack': True,
#   'isSupport': False},
#  {'topArgument': 'Having experience with sex and relationships does not make women impervious to the advances of manipulative men.',
#   'subArgument': 'This is especially true if these women were to have had relationships with non-manipulative, non-abusive men, as the experience of these relationships would not better prepare them for manipulative men.',
#   'subject': 'Are Purity Pledges Harmful?',
#   'subArgumentLevel': 5,
#   'domain': "['Purity', 'Sex', 'Virginity', 'Feminism', 'Women']",
#   'isAttack': False,
#   'isSupport': True},
#  {'topArgument': 'Having experience with sex and relationships does not make women impervious to the advances of manipulative men.',
#   'subArgument': "The parent claim isn't that experience with sex makes women completely impervious to manipulative men, just that it is better than no experience at all, which is what purity pledges provide.",
#   'subject': 'Are Purity Pledges Harmful?',
#   'subArgumentLevel': 5,
#   'domain': "['Purity', 'Sex', 'Virginity', 'Feminism', 'Women']",
#   'isAttack': True,
#   'isSupport': False},
#  {'topArgument': 'Women who do not have experience with sex and relationships may be more easily manipulated and lied to by predatory men.',
#   'subArgument': 'There is plenty of information and counseling available online and through social circles about manipulative behaviours that is easily accessible to women, regardless of their personal experience.',
#   'subject': 'Are Purity Pledges Harmful?',
#   'subArgumentLevel': 4,
#   'domain': "['Purity', 'Sex', 'Virginity', 'Feminism', 'Women']",
#   'isAttack': True,
#   'isSupport': False},
#  {'topArgument': 'There is plenty of information and counseling available online and through social circles about manipulative behaviours that is easily accessible to women, regardless of their personal experience.',
#   'subArgument': "The common manipulative tactic of 'gaslighting [49]' is now in the mainstream, and more visible and maligned than it used to be in the past.",
#   'subject': 'Are Purity Pledges Harmful?',
#   'subArgumentLevel': 5,
#   'domain': "['Purity', 'Sex', 'Virginity', 'Feminism', 'Women']",
#   'isAttack': False,
#   'isSupport': True},
#  {'topArgument': 'Purity pledges lead to women entering the sexual phase of their lives completely unprepared (p. 8 [31]). This leaves them very vulnerable to being used, manipulated, and abused.',
#   'subArgument': 'It is probable that the sort of people who become pledgers are, by virtue of their religious and communal upbringing, likely to have robust support systems and networks of family, churchgoers, and friends, all of whom can help to advise and counsel them about the choices they make and the people they meet in their lives.',
#   'subject': 'Are Purity Pledges Harmful?',
#   'subArgumentLevel': 3,
#   'domain': "['Purity', 'Sex', 'Virginity', 'Feminism', 'Women']",
#   'isAttack': True,
#   'isSupport': False},
#  {'topArgument': 'Purity pledges lead to women entering the sexual phase of their lives completely unprepared (p. 8 [31]). This leaves them very vulnerable to being used, manipulated, and abused.',
#   'subArgument': '-> See 1.1.2.4.3.',
#   'subject': 'Are Purity Pledges Harmful?',
#   'subArgumentLevel': 3,
#   'domain': "['Purity', 'Sex', 'Virginity', 'Feminism', 'Women']",
#   'isAttack': True,
#   'isSupport': False},
#  {'topArgument': 'Purity pledges lead to people having a poorer understanding of sexuality.',
#   'subArgument': 'There are a number of alternatives [50] to having pre-marital sex that allow a person to explore their sexuality and sexual preferences.',
#   'subject': 'Are Purity Pledges Harmful?',
#   'subArgumentLevel': 2,
#   'domain': "['Purity', 'Sex', 'Virginity', 'Feminism', 'Women']",
#   'isAttack': True,
#   'isSupport': False},
#  {'topArgument': 'There are a number of alternatives [50] to having pre-marital sex that allow a person to explore their sexuality and sexual preferences.',
#   'subArgument': 'Body exploration [51] or masturbation allows people to gain knowledge about their bodies, get in touch with their sensuality, and increase their comfort level when having sex. This in turn increases their ability to communicate their preferences to their partner.',
#   'subject': 'Are Purity Pledges Harmful?',
#   'subArgumentLevel': 3,
#   'domain': "['Purity', 'Sex', 'Virginity', 'Feminism', 'Women']",
#   'isAttack': False,
#   'isSupport': True},
#  {'topArgument': 'There are a number of alternatives [50] to having pre-marital sex that allow a person to explore their sexuality and sexual preferences.',
#   'subArgument': 'Podcasts [52] can provide insight about sex, answer questions that women may have, and help them discover things about their sexuality.',
#   'subject': 'Are Purity Pledges Harmful?',
#   'subArgumentLevel': 3,
#   'domain': "['Purity', 'Sex', 'Virginity', 'Feminism', 'Women']",
#   'isAttack': False,
#   'isSupport': True},
#  {'topArgument': 'There are a number of alternatives [50] to having pre-marital sex that allow a person to explore their sexuality and sexual preferences.',
#   'subArgument': 'Online classes and workshops [53] are available to help people discover and explore their sexuality.',
#   'subject': 'Are Purity Pledges Harmful?',
#   'subArgumentLevel': 3,
#   'domain': "['Purity', 'Sex', 'Virginity', 'Feminism', 'Women']",
#   'isAttack': False,
#   'isSupport': True},
#  {'topArgument': 'There are a number of alternatives [50] to having pre-marital sex that allow a person to explore their sexuality and sexual preferences.',
#   'subArgument': 'Parents often inform [54] their children about sex when they are below the age of consent.',
#   'subject': 'Are Purity Pledges Harmful?',
#   'subArgumentLevel': 3,
#   'domain': "['Purity', 'Sex', 'Virginity', 'Feminism', 'Women']",
#   'isAttack': False,
#   'isSupport': True},
#  {'topArgument': 'There are a number of alternatives [50] to having pre-marital sex that allow a person to explore their sexuality and sexual preferences.',
#   'subArgument': 'Schools can provide information [55] on sex even if students are not currently engaging in sex.',
#   'subject': 'Are Purity Pledges Harmful?',
#   'subArgumentLevel': 3,
#   'domain': "['Purity', 'Sex', 'Virginity', 'Feminism', 'Women']",
#   'isAttack': False,
#   'isSupport': True},
#  {'topArgument': 'There are a number of alternatives [50] to having pre-marital sex that allow a person to explore their sexuality and sexual preferences.',
#   'subArgument': '-> See 1.1.1.2.1.',
#   'subject': 'Are Purity Pledges Harmful?',
#   'subArgumentLevel': 3,
#   'domain': "['Purity', 'Sex', 'Virginity', 'Feminism', 'Women']",
#   'isAttack': True,
#   'isSupport': False},
#  {'topArgument': 'Purity pledges lead to people having a poorer understanding of sexuality.',
#   'subArgument': "There's nothing inherently wrong with learning about sex at a later age in life.",
#   'subject': 'Are Purity Pledges Harmful?',
#   'subArgumentLevel': 2,
#   'domain': "['Purity', 'Sex', 'Virginity', 'Feminism', 'Women']",
#   'isAttack': True,
#   'isSupport': False},
#  {'topArgument': "There's nothing inherently wrong with learning about sex at a later age in life.",
#   'subArgument': '-> See 1.1.1.5.',
#   'subject': 'Are Purity Pledges Harmful?',
#   'subArgumentLevel': 3,
#   'domain': "['Purity', 'Sex', 'Virginity', 'Feminism', 'Women']",
#   'isAttack': False,
#   'isSupport': True},
#  {'topArgument': 'Purity pledges lead to people having a poorer understanding of sexuality.',
#   'subArgument': 'A poorer understanding of sexuality is a worthwhile trade-off to avoid teenagers having pre-marital sex and possibly getting pregnant.',
#   'subject': 'Are Purity Pledges Harmful?',
#   'subArgumentLevel': 2,
#   'domain': "['Purity', 'Sex', 'Virginity', 'Feminism', 'Women']",
#   'isAttack': True,
#   'isSupport': False},
#  {'topArgument': 'A poorer understanding of sexuality is a worthwhile trade-off to avoid teenagers having pre-marital sex and possibly getting pregnant.',
#   'subArgument': 'Purity pledges reduce the amount of unwanted teenage pregnancies (p. 7 [56]).',
#   'subject': 'Are Purity Pledges Harmful?',
#   'subArgumentLevel': 3,
#   'domain': "['Purity', 'Sex', 'Virginity', 'Feminism', 'Women']",
#   'isAttack': False,
#   'isSupport': True},
#  {'topArgument': 'Purity pledges reduce the amount of unwanted teenage pregnancies (p. 7 [56]).',
#   'subArgument': 'A report (Marshall, Johnson, and Rector 2004 [57]) found that purity pledges reduce risk of teenage pregnancy and births.',
#   'subject': 'Are Purity Pledges Harmful?',
#   'subArgumentLevel': 4,
#   'domain': "['Purity', 'Sex', 'Virginity', 'Feminism', 'Women']",
#   'isAttack': False,
#   'isSupport': True},
#  {'topArgument': 'Purity pledges reduce the amount of unwanted teenage pregnancies (p. 7 [56]).',
#   'subArgument': 'A study [58] showed that the more abstinence was stressed, the higher were the rates of teen pregnancy and births.',
#   'subject': 'Are Purity Pledges Harmful?',
#   'subArgumentLevel': 4,
#   'domain': "['Purity', 'Sex', 'Virginity', 'Feminism', 'Women']",
#   'isAttack': True,
#   'isSupport': False},
#  {'topArgument': 'Purity pledges reduce the amount of unwanted teenage pregnancies (p. 7 [56]).',
#   'subArgument': 'A study showed that improved contraceptive use is responsible for 86 percent of the decline in the US adolescent pregnancy rate between 1995 and 2002 (p. 1 [59]).',
#   'subject': 'Are Purity Pledges Harmful?',
#   'subArgumentLevel': 4,
#   'domain': "['Purity', 'Sex', 'Virginity', 'Feminism', 'Women']",
#   'isAttack': True,
#   'isSupport': False},
#  {'topArgument': 'A study showed that improved contraceptive use is responsible for 86 percent of the decline in the US adolescent pregnancy rate between 1995 and 2002 (p. 1 [59]).',
#   'subArgument': 'The same study showed that 14% of the drop in teen pregnancy was abstinence (p. 154 [60]).',
#   'subject': 'Are Purity Pledges Harmful?',
#   'subArgumentLevel': 5,
#   'domain': "['Purity', 'Sex', 'Virginity', 'Feminism', 'Women']",
#   'isAttack': True,
#   'isSupport': False},
#  {'topArgument': 'Purity pledges reduce the amount of unwanted teenage pregnancies (p. 7 [56]).',
#   'subArgument': 'Studies show that individuals who make a private pledge to themselves are less likely to have sex before marriage (p. 8 [61]).',
#   'subject': 'Are Purity Pledges Harmful?',
#   'subArgumentLevel': 4,
#   'domain': "['Purity', 'Sex', 'Virginity', 'Feminism', 'Women']",
#   'isAttack': False,
#   'isSupport': True},
#  {'topArgument': 'Studies show that individuals who make a private pledge to themselves are less likely to have sex before marriage (p. 8 [61]).',
#   'subArgument': 'A private pledge to not have pre-marital sex can exist without all the social and familial pressure that public purity pledges involve.',
#   'subject': 'Are Purity Pledges Harmful?',
#   'subArgumentLevel': 5,
#   'domain': "['Purity', 'Sex', 'Virginity', 'Feminism', 'Women']",
#   'isAttack': True,
#   'isSupport': False},
#  {'topArgument': 'Purity pledges reduce the amount of unwanted teenage pregnancies (p. 7 [56]).',
#   'subArgument': 'Those people who make a pledge but fail to stick to it actually have increased risks of unwanted pregnancy and disease (p. 2 [62]).',
#   'subject': 'Are Purity Pledges Harmful?',
#   'subArgumentLevel': 4,
#   'domain': "['Purity', 'Sex', 'Virginity', 'Feminism', 'Women']",
#   'isAttack': True,
#   'isSupport': False},
#  {'topArgument': 'A poorer understanding of sexuality is a worthwhile trade-off to avoid teenagers having pre-marital sex and possibly getting pregnant.',
#   'subArgument': 'The incidence [63] of pregnancy was 30% for pledgers as compared to 18% for non-pledgers.',
#   'subject': 'Are Purity Pledges Harmful?',
#   'subArgumentLevel': 3,
#   'domain': "['Purity', 'Sex', 'Virginity', 'Feminism', 'Women']",
#   'isAttack': True,
#   'isSupport': False},
#  {'topArgument': 'A poorer understanding of sexuality is a worthwhile trade-off to avoid teenagers having pre-marital sex and possibly getting pregnant.',
#   'subArgument': '-> See 1.1.5.1.5.',
#   'subject': 'Are Purity Pledges Harmful?',
#   'subArgumentLevel': 3,
#   'domain': "['Purity', 'Sex', 'Virginity', 'Feminism', 'Women']",
#   'isAttack': True,
#   'isSupport': False},
#  {'topArgument': 'Purity pledges lead to people having a poorer understanding of sexuality.',
#   'subArgument': 'Purity culture goes beyond abstinence [64] - it has to be accompanied by a total commitment to repressing every aspect of your sexuality and conforming to acceptable standards of sexuality.',
#   'subject': 'Are Purity Pledges Harmful?',
#   'subArgumentLevel': 2,
#   'domain': "['Purity', 'Sex', 'Virginity', 'Feminism', 'Women']",
#   'isAttack': False,
#   'isSupport': True},
#  {'topArgument': 'Purity culture goes beyond abstinence [64] - it has to be accompanied by a total commitment to repressing every aspect of your sexuality and conforming to acceptable standards of sexuality.',
#   'subArgument': '-> See 1.1.1.2.1.',
#   'subject': 'Are Purity Pledges Harmful?',
#   'subArgumentLevel': 3,
# ...
#   'subArgument': 'This number includes private-sector spending; the combined control of a one world state over this budget would only be possible under a global, centrally-planned economy, which would be bad.',
#   'subject': 'Should there be One World State?',
#   'subArgumentLevel': 5,
#   'domain': "['States', 'Nations', 'Culture', 'Economics', 'Politics']",
#   'isAttack': True,
#   'isSupport': False},
#  {'topArgument': 'A one world state would have the ability to optimally allocate and coordinate all scientific and technological resources.',
#   'subArgument': 'Research [104] shows that problems associated with scientific and technological resource allocation and management can cause viruses to spread rapidly. Optimal allocation and coordination of these resources would allow quicker and more efficient tackling of such viruses.',
#   'subject': 'Should there be One World State?',
#   'subArgumentLevel': 4,
#   'domain': "['States', 'Nations', 'Culture', 'Economics', 'Politics']",
#   'isAttack': False,
#   'isSupport': True},
#  {'topArgument': 'The formation of this state would lead to incredible advancements in science and technology.',
#   'subArgument': 'Most scientific and technological advancements are made by private businesses and universities, not by governments.',
#   'subject': 'Should there be One World State?',
#   'subArgumentLevel': 3,
#   'domain': "['States', 'Nations', 'Culture', 'Economics', 'Politics']",
#   'isAttack': True,
#   'isSupport': False},
#  {'topArgument': 'Most scientific and technological advancements are made by private businesses and universities, not by governments.',
#   'subArgument': 'According to the OECD [105], about 60% of scientific funding is given by industry, with another 20% by universities.',
#   'subject': 'Should there be One World State?',
#   'subArgumentLevel': 4,
#   'domain': "['States', 'Nations', 'Culture', 'Economics', 'Politics']",
#   'isAttack': False,
#   'isSupport': True},
#  {'topArgument': 'Most scientific and technological advancements are made by private businesses and universities, not by governments.',
#   'subArgument': 'Universities are often [106] government-funded, and a one world state would be better able to allocate funding to the right universities.',
#   'subject': 'Should there be One World State?',
#   'subArgumentLevel': 4,
#   'domain': "['States', 'Nations', 'Culture', 'Economics', 'Politics']",
#   'isAttack': True,
#   'isSupport': False},
#  {'topArgument': 'The formation of this state would lead to incredible advancements in science and technology.',
#   'subArgument': '-> See 1.1.2.1.3.',
#   'subject': 'Should there be One World State?',
#   'subArgumentLevel': 3,
#   'domain': "['States', 'Nations', 'Culture', 'Economics', 'Politics']",
#   'isAttack': True,
#   'isSupport': False},
#  {'topArgument': 'The formation of a one world state would lead to immense economic and material benefits.',
#   'subArgument': 'A world without borders would result in severe economic harms.',
#   'subject': 'Should there be One World State?',
#   'subArgumentLevel': 2,
#   'domain': "['States', 'Nations', 'Culture', 'Economics', 'Politics']",
#   'isAttack': True,
#   'isSupport': False},
#  {'topArgument': 'A world without borders would result in severe economic harms.',
#   'subArgument': '-> See 1.1.4.',
#   'subject': 'Should there be One World State?',
#   'subArgumentLevel': 3,
#   'domain': "['States', 'Nations', 'Culture', 'Economics', 'Politics']",
#   'isAttack': True,
#   'isSupport': False},
#  {'topArgument': 'A world without borders would result in severe economic harms.',
#   'subArgument': 'Individuals in the Global South [107] would be incentivised to carry out a mass migration to the Global North in hopes of a better life, negatively impacting the prosperity of developing regions in the Global South.',
#   'subject': 'Should there be One World State?',
#   'subArgumentLevel': 3,
#   'domain': "['States', 'Nations', 'Culture', 'Economics', 'Politics']",
#   'isAttack': False,
#   'isSupport': True},
#  {'topArgument': 'Individuals in the Global South [107] would be incentivised to carry out a mass migration to the Global North in hopes of a better life, negatively impacting the prosperity of developing regions in the Global South.',
#   'subArgument': "This isn't necessarily an overall evil, as these individuals will be able to seek better lives for themselves.",
#   'subject': 'Should there be One World State?',
#   'subArgumentLevel': 4,
#   'domain': "['States', 'Nations', 'Culture', 'Economics', 'Politics']",
#   'isAttack': True,
#   'isSupport': False},
#  {'topArgument': "This isn't necessarily an overall evil, as these individuals will be able to seek better lives for themselves.",
#   'subArgument': "The needs of these people's communities matter more than what the individuals themselves want.",
#   'subject': 'Should there be One World State?',
#   'subArgumentLevel': 5,
#   'domain': "['States', 'Nations', 'Culture', 'Economics', 'Politics']",
#   'isAttack': True,
#   'isSupport': False},
#  {'topArgument': "The needs of these people's communities matter more than what the individuals themselves want.",
#   'subArgument': 'These individuals usually represent the privileged top brass of these communities. Ethically speaking, the needs of the poor, who have no options, should come before the luxuries of the better off.',
#   'subject': 'Should there be One World State?',
#   'subArgumentLevel': 6,
#   'domain': "['States', 'Nations', 'Culture', 'Economics', 'Politics']",
#   'isAttack': False,
#   'isSupport': True},
#  {'topArgument': "This isn't necessarily an overall evil, as these individuals will be able to seek better lives for themselves.",
#   'subArgument': 'These people should not have their ambitions and dreams held hostage by the communities they came from.',
#   'subject': 'Should there be One World State?',
#   'subArgumentLevel': 5,
#   'domain': "['States', 'Nations', 'Culture', 'Economics', 'Politics']",
#   'isAttack': False,
#   'isSupport': True},
#  {'topArgument': 'Individuals in the Global South [107] would be incentivised to carry out a mass migration to the Global North in hopes of a better life, negatively impacting the prosperity of developing regions in the Global South.',
#   'subArgument': 'From 2000 to 2017, half [108] of the total increase in international migration took place in developing countries of the Global South and half in developed countries of the Global North. This suggests that the current predominant discourse on international migration overemphasises the flow of migrants from the Global South to the Global North.',
#   'subject': 'Should there be One World State?',
#   'subArgumentLevel': 4,
#   'domain': "['States', 'Nations', 'Culture', 'Economics', 'Politics']",
#   'isAttack': True,
#   'isSupport': False},
#  {'topArgument': 'Individuals in the Global South [107] would be incentivised to carry out a mass migration to the Global North in hopes of a better life, negatively impacting the prosperity of developing regions in the Global South.',
#   'subArgument': 'Mass migration will cause a massive brain drain [109] for the developing regions in the Global South, further crippling development in those regions.',
#   'subject': 'Should there be One World State?',
#   'subArgumentLevel': 4,
#   'domain': "['States', 'Nations', 'Culture', 'Economics', 'Politics']",
#   'isAttack': False,
#   'isSupport': True},
#  {'topArgument': 'Mass migration will cause a massive brain drain [109] for the developing regions in the Global South, further crippling development in those regions.',
#   'subArgument': 'As developed regions in the Global North are likely to have a limited number of jobs [110], many skilled workers may choose to stay in or even immigrate to the Global South for employment.',
#   'subject': 'Should there be One World State?',
#   'subArgumentLevel': 5,
#   'domain': "['States', 'Nations', 'Culture', 'Economics', 'Politics']",
#   'isAttack': True,
#   'isSupport': False},
#  {'topArgument': 'Mass migration will cause a massive brain drain [109] for the developing regions in the Global South, further crippling development in those regions.',
#   'subArgument': 'Studies have shown that brain drain can significantly harm the countries that individuals emigrate from.',
#   'subject': 'Should there be One World State?',
#   'subArgumentLevel': 5,
#   'domain': "['States', 'Nations', 'Culture', 'Economics', 'Politics']",
#   'isAttack': False,
#   'isSupport': True},
#  {'topArgument': 'Studies have shown that brain drain can significantly harm the countries that individuals emigrate from.',
#   'subArgument': 'Research [111] has shown that brain drain actually has a positive effect on the country of origin.',
#   'subject': 'Should there be One World State?',
#   'subArgumentLevel': 6,
#   'domain': "['States', 'Nations', 'Culture', 'Economics', 'Politics']",
#   'isAttack': True,
#   'isSupport': False},
#  {'topArgument': 'Research [111] has shown that brain drain actually has a positive effect on the country of origin.',
#   'subArgument': 'Much research indicating possible positive effects of a brain drain does not necessarily vouch that it is net beneficial or that there are no negative effects, but rather that the negative effects can be exaggerated [112].',
#   'subject': 'Should there be One World State?',
#   'subArgumentLevel': 7,
#   'domain': "['States', 'Nations', 'Culture', 'Economics', 'Politics']",
#   'isAttack': True,
#   'isSupport': False},
#  {'topArgument': 'Research [111] has shown that brain drain actually has a positive effect on the country of origin.',
#   'subArgument': 'Young people that immigrate to developed countries acquire education and experience, and then return home to add to the stock of human capital.',
#   'subject': 'Should there be One World State?',
#   'subArgumentLevel': 7,
#   'domain': "['States', 'Nations', 'Culture', 'Economics', 'Politics']",
#   'isAttack': False,
#   'isSupport': True},
#  {'topArgument': 'Young people that immigrate to developed countries acquire education and experience, and then return home to add to the stock of human capital.',
#   'subArgument': 'In a study [113] on migrants returning to Central America from the USA, it was found that the returning migrants were both highly common and invaluable for the local economy in their home country, using their US-acquired skills to promote economic development.',
#   'subject': 'Should there be One World State?',
#   'subArgumentLevel': 8,
#   'domain': "['States', 'Nations', 'Culture', 'Economics', 'Politics']",
#   'isAttack': False,
#   'isSupport': True},
#  {'topArgument': 'Young people that immigrate to developed countries acquire education and experience, and then return home to add to the stock of human capital.',
#   'subArgument': 'Many people only return to their home country because of the stipulations of specific scholarships [114] - it is very possible that these scholarships would no longer force these conditions upon them in a world without nations.',
#   'subject': 'Should there be One World State?',
#   'subArgumentLevel': 8,
#   'domain': "['States', 'Nations', 'Culture', 'Economics', 'Politics']",
#   'isAttack': True,
#   'isSupport': False},
#  {'topArgument': 'Young people that immigrate to developed countries acquire education and experience, and then return home to add to the stock of human capital.',
#   'subArgument': 'A study [115] of Turkish migrants from Germany shows that about half of them started their own business following their return. (pp. 352-353)',
#   'subject': 'Should there be One World State?',
#   'subArgumentLevel': 8,
#   'domain': "['States', 'Nations', 'Culture', 'Economics', 'Politics']",
#   'isAttack': False,
#   'isSupport': True},
#  {'topArgument': 'Research [111] has shown that brain drain actually has a positive effect on the country of origin.',
#   'subArgument': 'Emigrants often send large flows of remittances [116] back to their families in their home country.',
#   'subject': 'Should there be One World State?',
#   'subArgumentLevel': 7,
#   'domain': "['States', 'Nations', 'Culture', 'Economics', 'Politics']",
#   'isAttack': False,
#   'isSupport': True},
#  {'topArgument': 'Studies have shown that brain drain can significantly harm the countries that individuals emigrate from.',
#   'subArgument': 'One study [117] showed that India lost as much as $2 billion a year on technical investment due to brain drain.',
#   'subject': 'Should there be One World State?',
#   'subArgumentLevel': 6,
#   'domain': "['States', 'Nations', 'Culture', 'Economics', 'Politics']",
#   'isAttack': False,
#   'isSupport': True},
#  {'topArgument': 'Studies have shown that brain drain can significantly harm the countries that individuals emigrate from.',
#   'subArgument': 'A report [118] by the British Medical Journal notes that weak healthcare systems in sub-Saharan African countries are greatly threatened by the emigration of doctors to wealthier countries.',
#   'subject': 'Should there be One World State?',
#   'subArgumentLevel': 6,
#   'domain': "['States', 'Nations', 'Culture', 'Economics', 'Politics']",
#   'isAttack': False,
#   'isSupport': True},
#  {'topArgument': 'Individuals in the Global South [107] would be incentivised to carry out a mass migration to the Global North in hopes of a better life, negatively impacting the prosperity of developing regions in the Global South.',
#   'subArgument': 'As of 2017, nearly 710 million adults around the world stated that they wanted to permanently migrate to another country, with the majority [119] of their top desired destinations worldwide being countries in the Global North.',
#   'subject': 'Should there be One World State?',
#   'subArgumentLevel': 4,
#   'domain': "['States', 'Nations', 'Culture', 'Economics', 'Politics']",
#   'isAttack': False,
#   'isSupport': True},
#  {'topArgument': 'A world without borders would result in severe economic harms.',
#   'subArgument': 'Small scale local industries could go out of business in a failed attempt to compete [120] with big, large-scale industries, which would be able to expand their operations without any added cost.',
#   'subject': 'Should there be One World State?',
#   'subArgumentLevel': 3,
#   'domain': "['States', 'Nations', 'Culture', 'Economics', 'Politics']",
#   'isAttack': False,
#   'isSupport': True},
#  {'topArgument': 'Small scale local industries could go out of business in a failed attempt to compete [120] with big, large-scale industries, which would be able to expand their operations without any added cost.',
#   'subArgument': 'The only reason these smaller-scale industries can survive right now is because countries are able to pursue protectionist [121] economic policies.',
#   'subject': 'Should there be One World State?',
#   'subArgumentLevel': 4,
#   'domain': "['States', 'Nations', 'Culture', 'Economics', 'Politics']",
#   'isAttack': False,
#   'isSupport': True},
#  {'topArgument': 'Small scale local industries could go out of business in a failed attempt to compete [120] with big, large-scale industries, which would be able to expand their operations without any added cost.',
#   'subArgument': '-> See 1.1.4.7.7.2.1.',
#   'subject': 'Should there be One World State?',
#   'subArgumentLevel': 4,
#   'domain': "['States', 'Nations', 'Culture', 'Economics', 'Politics']",
#   'isAttack': True,
#   'isSupport': False},
#  {'topArgument': 'A world without borders would result in severe economic harms.',
#   'subArgument': '-> See 1.1.4.7.',
#   'subject': 'Should there be One World State?',
#   'subArgumentLevel': 3,
#   'domain': "['States', 'Nations', 'Culture', 'Economics', 'Politics']",
#   'isAttack': True,
#   'isSupport': False},
#  {'topArgument': 'The formation of a one world state would solve collective action problems [122] more effectively.',
#   'subArgument': 'Global pandemics such as the COVID-19 outbreak could arguably be mitigated or resolved much more efficiently in a one world state context.',
#   'subject': 'Should there be One World State?',
#   'subArgumentLevel': 2,
#   'domain': "['States', 'Nations', 'Culture', 'Economics', 'Politics']",
#   'isAttack': False,
#   'isSupport': True},
#  ...]

# %%
pairs[0]
# Out:
# {'topArgument': 'Purity pledges lead to people having a poorer understanding of sexuality.',
#  'subArgument': 'Purity pledges lead to people not having a proper understanding of the potential consequences of sex.',
#  'subject': 'Are Purity Pledges Harmful?',
#  'subArgumentLevel': 2,
#  'domain': "['Purity', 'Sex', 'Virginity', 'Feminism', 'Women']",
#  'isAttack': False,
#  'isSupport': True}

# %%
argSrc = [x["subArgument"] for x in pairs]
argTrg = [x["topArgument"] for x in pairs]
datasetSource = ["kialo" for x in pairs]
topic = [x["domain"] for x in pairs]
relations = ["attack" if x["isAttack"] else "support" for x in pairs]

d = pd.DataFrame.from_dict({
  "topic": topic,
  "relation" : relations,
  "argSrc" : argSrc,
  "argTrg" : argTrg,
  "datasetSource" : datasetSource
})

d
# Out:
#                                                     topic relation  \
# 0       ['Purity', 'Sex', 'Virginity', 'Feminism', 'Wo...  support
# 1       ['Purity', 'Sex', 'Virginity', 'Feminism', 'Wo...  support
# 2       ['Purity', 'Sex', 'Virginity', 'Feminism', 'Wo...  support
# 3       ['Purity', 'Sex', 'Virginity', 'Feminism', 'Wo...  support
# 4       ['Purity', 'Sex', 'Virginity', 'Feminism', 'Wo...  support
# ...                                                   ...      ...
# 166380        ['Gender', 'VideoGames', 'Media', 'Sexism']  support
# 166381        ['Gender', 'VideoGames', 'Media', 'Sexism']   attack
# 166382        ['Gender', 'VideoGames', 'Media', 'Sexism']  support
# 166383        ['Gender', 'VideoGames', 'Media', 'Sexism']  support
# 166384        ['Gender', 'VideoGames', 'Media', 'Sexism']   attack
#
#                                                    argSrc  \
# 0       Purity pledges lead to people not having a pro...
# 1       Purity pledges are a facet of abstinence-only ...
# 2       Abstinence programmes are likely to lead to pe...
# 3       Pledgers often believe contraceptives are unre...
# 4       Abstinence programmes push against [3] increas...
# ...                                                   ...
# 166380  Gamers in the community have made [251] explos...
# 166381  There are ample ads that depict, for example, ...
# 166382  Media industries (including video games) have ...
# 166383  Societies higher in gender equality are less v...
# 166384  There are many laudable things we as a society...
#
#                                                    argTrg datasetSource
# 0       Purity pledges lead to people having a poorer ...         kialo
# 1       Purity pledges lead to people not having a pro...         kialo
# 2       Purity pledges are a facet of abstinence-only ...         kialo
# 3       Abstinence programmes are likely to lead to pe...         kialo
# 4       Abstinence programmes are likely to lead to pe...         kialo
# ...                                                   ...           ...
# 166380  The eleventh installment of Mortal Kombat came...         kialo
# 166381  In so far as the world is aiming for gender eq...         kialo
# 166382  In so far as the world is aiming for gender eq...         kialo
# 166383  In so far as the world is aiming for gender eq...         kialo
# 166384  In so far as the world is aiming for gender eq...         kialo
#
# [166385 rows x 5 columns]

# %%
d.to_csv("kialoPairs.csv")
