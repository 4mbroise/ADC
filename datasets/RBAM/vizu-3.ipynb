# %% [markdown]
# # TRAIN DATASET

# %%
import pandas as pd

# %%
mergedDf = pd.read_csv("./RBAM-dataset-3-TRAIN.csv", index_col=0)
mergedDf
# Out:
#                                                     topic relation  \
# 80400   ['Religion', 'Taxation', 'Society', 'Government']   attack
# 100427       ['Religion', 'Philosophy', 'Science', 'God']   attack
# 27553                                             unknown  neither
# 136157  ['Society', 'Education', 'Economics', 'Languag...  support
# 8498                                              unknown  neither
# ...                                                   ...      ...
# 145995         ['Health', 'Ethics', 'Law', 'HumanRights']   attack
# 132563  ['Law', 'Government', 'Ethics', 'Society', 'Po...  support
# 9735    ['Religion', 'God', 'Bible', 'Faith', 'Christi...   attack
# 65860             ['War', 'Middleeast', 'Israel', 'Gaza']  support
# 160305                 ['Philosophy', 'Life', 'Religion']   attack
#
#                                                    argSrc  \
# 80400   Secular moral codes do not have the same divin...
# 100427  The assumed premise here is only that the caus...
# 27553   The painting's distorted and fragmented imager...
# 136157  Many famous books have been translated [101] i...
# 8498    it also had some negative effects such as expl...
# ...                                                   ...
# 145995  Generating mistrust in the government, the hea...
# 132563  Eyewitnesses can appear so confident in their ...
# 9735    Insofar as the meaning of a text depends upon ...
# 65860   The failures of the US [65] to engage its Midd...
# 160305  Creativity [25] and critical thinking [26] are...
#
#                                                    argTrg datasetSource
# 80400   Moral codes ingrained through secular teaching...         kialo
# 100427  A transcendent Creator's omnipotence is not a ...         kialo
# 27553   These advancements in art have been seen as th...        argGpt
# 136157  The power of expressing complex ideas is the s...         kialo
# 8498    It created new jobs and opportunities for Egyp...        argGpt
# ...                                                   ...           ...
# 145995  It is possible that people would mistrust the ...         kialo
# 132563  Jurors that vote unanimously can still make a ...         kialo
# 9735    Even if there are contradictions in the Bible,...         kialo
# 65860   There is reason for Middle Eastern nations to ...         kialo
# 160305  A study of 87 countries [24] found that religi...         kialo
#
# [126832 rows x 5 columns]

# %% [markdown]
# # By relation

# %%
count = mergedDf.groupby('relation').count()
count["count"] = count["argSrc"]
count = count.drop(columns=["argSrc", "argTrg", "topic", "datasetSource"])

count
# Out:
#           count
# relation
# attack    42205
# neither   42359
# support   42268

# %%
count.T
# Out:
# relation  attack  neither  support
# count      42205    42359    42268

# %%
count.T.plot(kind='bar', color=['tomato','lightblue','greenyellow'])
# Out:
# <Axes: >

# %%
count.T.plot(kind='bar', color=['tomato','lightblue','greenyellow'], stacked=True)
# Out:
# <Axes: >

# %% [markdown]
# ## By source

# %%
mergedDf = pd.read_csv("./RBAM-dataset-2.csv", index_col=0)
count = mergedDf.groupby('datasetSource').count()
count["count"] = count["argSrc"]
count = count.drop(columns=["topic", "relation", "argSrc", "argTrg"])
count
# Out:
#                           count
# datasetSource
# arg-microtexts             2306
# argGpt                    55349
# kialo                    109800
# political-argumentation    1655

# %%
count.T.plot(kind='bar', color=['tomato','lightblue','greenyellow'])
# Out:
# <Axes: >

# %%
count.T.plot(kind='bar', color=['tomato','lightblue','greenyellow'], stacked=True)
# Out:
# <Axes: >

# %%
mergedDf = pd.read_csv("./RBAM-dataset-2.csv", index_col=0)
count = mergedDf.groupby(["datasetSource", "relation"]).count()
count = mergedDf.groupby(["datasetSource", "relation"]).count()
count = count.rename(columns={"topic": "count"})
count = count.drop(columns=["argSrc", "argTrg"])
count
# Out:
#                                   count
# datasetSource           relation
# arg-microtexts          attack      116
#                         neither    2000
#                         support     190
# argGpt                  attack      471
#                         neither   53197
#                         support    1681
# kialo                   attack    55530
#                         support   54270
# political-argumentation attack      253
#                         neither    1173
#                         support     229

# %%
count.plot(kind='bar', color=['tomato','lightblue','greenyellow'])
# Out:
# <Axes: xlabel='datasetSource,relation'>

# %%
mergedDf = pd.read_csv("./RBAM-dataset-2.csv", index_col=0)
count = mergedDf.groupby(["topic"]).count()
count
# Out:
#                                                     relation  argSrc  argTrg  \
# topic
# ['2000']                                                   3       3       3
# ['ADC', 'Bitcoin', 'Anonymity', 'Blockchain', '...       277     277     277
# ['AGI', 'GPT', 'ChatGPT', 'AI', 'GPT-4']                  23      23      23
# ['AI', 'Art']                                             34      34      34
# ['AI', 'ChatGPT', 'Work', 'Productivity']                 86      86      86
# ...                                                      ...     ...     ...
# disarmament                                              311     311     311
# medical care,health care                                 344     344     344
# minimum wage                                             314     314     314
# unemployment                                             331     331     331
# unknown                                                57655   57655   57655
#
#                                                     datasetSource
# topic
# ['2000']                                                        3
# ['ADC', 'Bitcoin', 'Anonymity', 'Blockchain', '...            277
# ['AGI', 'GPT', 'ChatGPT', 'AI', 'GPT-4']                       23
# ['AI', 'Art']                                                  34
# ['AI', 'ChatGPT', 'Work', 'Productivity']                      86
# ...                                                           ...
# disarmament                                                   311
# medical care,health care                                      344
# minimum wage                                                  314
# unemployment                                                  331
# unknown                                                     57655
#
# [686 rows x 4 columns]

# %% [markdown]
# # TEST DATASET

# %%
import pandas as pd

# %%
mergedDf = pd.read_csv("./RBAM-dataset-3-TEST.csv", index_col=0)
mergedDf
# Out:
#                                                     topic relation  \
# 131115            ['Coronavirus', 'COVID-19', 'Vaccines']   attack
# 55098       ['Ethics', 'Society', 'Technology', 'Health']  support
# 29847                                             unknown  neither
# 152135                     ['History', 'Religion', 'God']  support
# 15167                                             unknown  neither
# ...                                                   ...      ...
# 38735                                             unknown  neither
# 38849                                             unknown  neither
# 45831                                             unknown  neither
# 52007   ['Society', 'Ethics', 'Philosophy', 'Environme...  support
# 19814                                             unknown  neither
#
#                                                    argSrc  \
# 131115  Certain groups are already at higher risk [92]...
# 55098   Instagram [24] has been linked to teenagers' i...
# 29847   Skyrim was likely inspired by other games, inc...
# 152135  In Adam Clarke's commentary to Isaiah 29:4 [46...
# 15167         the Nazi party was fiercely anti-capitalist
# ...                                                   ...
# 38735   This means that time can appear to pass more s...
# 38849   According to Einstein, space and time are not ...
# 45831              it may seem surprising at first glance
# 52007   The Earth has been formed for human life. The ...
# 19814   it is incorrect to suggest that they laid the ...
#
#                                                    argTrg datasetSource
# 131115  Differences over how to distribute the vaccine...         kialo
# 55098   People have been shown to experience depressio...         kialo
# 29847   Another factor that challenges the claim that ...        argGpt
# 152135  The Book of Mormon portrays Joseph Smith's man...         kialo
# 15167   The Nazi party's full name was the National So...        argGpt
# ...                                                   ...           ...
# 38735   it can be argued that the constant speed of li...        argGpt
# 38849   This means that time can appear to pass more s...        argGpt
# 45831   Veloso and Strauss II belong to different genr...        argGpt
# 52007   From a theistic God viewpoint, the world was m...         kialo
# 19814   The War of the Roses was a complex and multifa...        argGpt
#
# [33822 rows x 5 columns]

# %% [markdown]
# # By relation

# %%
count = mergedDf.groupby('relation').count()
count["count"] = count["argSrc"]
count = count.drop(columns=["argSrc", "argTrg", "topic", "datasetSource"])

count
# Out:
#           count
# relation
# attack    11306
# neither   11211
# support   11305

# %%
count.T
# Out:
# relation  attack  neither  support
# count      11306    11211    11305

# %%
count.T.plot(kind='bar', color=['tomato','lightblue','greenyellow'])
# Out:
# <Axes: >

# %%
count.T.plot(kind='bar', color=['tomato','lightblue','greenyellow'], stacked=True)
# Out:
# <Axes: >

# %% [markdown]
# ## By source

# %%
mergedDf = pd.read_csv("./RBAM-dataset-2.csv", index_col=0)
count = mergedDf.groupby('datasetSource').count()
count["count"] = count["argSrc"]
count = count.drop(columns=["topic", "relation", "argSrc", "argTrg"])
count
# Out:
#                           count
# datasetSource
# arg-microtexts             2306
# argGpt                    55349
# kialo                    109800
# political-argumentation    1655

# %%
count.T.plot(kind='bar', color=['tomato','lightblue','greenyellow'])
# Out:
# <Axes: >

# %%
count.T.plot(kind='bar', color=['tomato','lightblue','greenyellow'], stacked=True)
# Out:
# <Axes: >

# %%
mergedDf = pd.read_csv("./RBAM-dataset-2.csv", index_col=0)
count = mergedDf.groupby(["datasetSource", "relation"]).count()
count = mergedDf.groupby(["datasetSource", "relation"]).count()
count = count.rename(columns={"topic": "count"})
count = count.drop(columns=["argSrc", "argTrg"])
count
# Out:
#                                   count
# datasetSource           relation
# arg-microtexts          attack      116
#                         neither    2000
#                         support     190
# argGpt                  attack      471
#                         neither   53197
#                         support    1681
# kialo                   attack    55530
#                         support   54270
# political-argumentation attack      253
#                         neither    1173
#                         support     229

# %%
count.plot(kind='bar', color=['tomato','lightblue','greenyellow'])
# Out:
# <Axes: xlabel='datasetSource,relation'>

# %%
mergedDf = pd.read_csv("./RBAM-dataset-2.csv", index_col=0)
count = mergedDf.groupby(["topic"]).count()
count
# Out:
#                                                     relation  argSrc  argTrg  \
# topic
# ['2000']                                                   3       3       3
# ['ADC', 'Bitcoin', 'Anonymity', 'Blockchain', '...       277     277     277
# ['AGI', 'GPT', 'ChatGPT', 'AI', 'GPT-4']                  23      23      23
# ['AI', 'Art']                                             34      34      34
# ['AI', 'ChatGPT', 'Work', 'Productivity']                 86      86      86
# ...                                                      ...     ...     ...
# disarmament                                              311     311     311
# medical care,health care                                 344     344     344
# minimum wage                                             314     314     314
# unemployment                                             331     331     331
# unknown                                                57655   57655   57655
#
#                                                     datasetSource
# topic
# ['2000']                                                        3
# ['ADC', 'Bitcoin', 'Anonymity', 'Blockchain', '...            277
# ['AGI', 'GPT', 'ChatGPT', 'AI', 'GPT-4']                       23
# ['AI', 'Art']                                                  34
# ['AI', 'ChatGPT', 'Work', 'Productivity']                      86
# ...                                                           ...
# disarmament                                                   311
# medical care,health care                                      344
# minimum wage                                                  314
# unemployment                                                  331
# unknown                                                     57655
#
# [686 rows x 4 columns]

# %% [markdown]
# # EVAL DATASET

# %%
import pandas as pd

# %%
mergedDf = pd.read_csv("./RBAM-dataset-3-EVAL.csv", index_col=0)
mergedDf
# Out:
#                                                     topic relation  \
# 4777    ['Refugees', 'Ethics', 'Politics', 'Immigratio...  support
# 107877  ['Politics', 'Palestine', 'Israel', 'China', '...   attack
# 72933   ['Environment', 'Law', 'ClimateChange', 'Cars'...   attack
# 4839    ['Refugees', 'Ethics', 'Politics', 'Immigratio...  support
# 157351    ['Environment', 'ClimateChange', 'Taxes', 'EU']  support
# ...                                                   ...      ...
# 76545   ['Politics', 'Ethics', 'Capitalism', 'Communism']  support
# 107297      ['Education', 'College', 'Student', 'Wealth']  support
# 51947                                             unknown  neither
# 15427                                             unknown  neither
# 105025  ['Religion', 'Christianity', 'Ethics', 'Cathol...  support
#
#                                                    argSrc  \
# 4777    The UN Convention on the Law of the Sea prescr...
# 107877  The October 7th attack was one attack in a lar...
# 72933   Banning cars will make cities less safe in som...
# 4839    Refugees from Afghanistan, the second-largest ...
# 157351                                    -> See 1.2.1.1.
# ...                                                   ...
# 76545   Once the capital interest are removed, all wor...
# 107297  If a family's annual income goes below [134] a...
# 51947   Beauty is a highly subjective and personal exp...
# 15427   The party's socialist economic policies, anti-...
# 105025                              -> See 1.1.6.2.3.3.2.
#
#                                                    argTrg datasetSource
# 4777    Some countries [105] abide by Duty to Rescue [...         kialo
# 107877  The most recent conflict was instigated by a t...         kialo
# 72933   Cities without private cars would be safer, as...         kialo
# 4839    Mass migration is often directly tied to a loc...         kialo
# 157351  Increased carbon emissions have had devastatin...         kialo
# ...                                                   ...           ...
# 76545   In a communist system, working class rights ar...         kialo
# 107297  Even though Ivy League colleges are expensive,...         kialo
# 51947     this does not necessarily make it a French city        argGpt
# 15427   Some argue that Nazism, in fact, shares many s...        argGpt
# 105025  Pope Francis has not changed [70] the Church's...         kialo
#
# [8456 rows x 5 columns]

# %% [markdown]
# # By relation

# %%
count = mergedDf.groupby('relation').count()
count["count"] = count["argSrc"]
count = count.drop(columns=["argSrc", "argTrg", "topic", "datasetSource"])

count
# Out:
#           count
# relation
# attack     2859
# neither    2800
# support    2797

# %%
count.T
# Out:
# relation  attack  neither  support
# count       2859     2800     2797

# %%
count.T.plot(kind='bar', color=['tomato','lightblue','greenyellow'])
# Out:
# <Axes: >

# %%
count.T.plot(kind='bar', color=['tomato','lightblue','greenyellow'], stacked=True)
# Out:
# <Axes: >

# %% [markdown]
# ## By source

# %%
mergedDf = pd.read_csv("./RBAM-dataset-2.csv", index_col=0)
count = mergedDf.groupby('datasetSource').count()
count["count"] = count["argSrc"]
count = count.drop(columns=["topic", "relation", "argSrc", "argTrg"])
count
# Out:
#                           count
# datasetSource
# arg-microtexts             2306
# argGpt                    55349
# kialo                    109800
# political-argumentation    1655

# %%
count.T.plot(kind='bar', color=['tomato','lightblue','greenyellow'])
# Out:
# <Axes: >

# %%
count.T.plot(kind='bar', color=['tomato','lightblue','greenyellow'], stacked=True)
# Out:
# <Axes: >

# %%
mergedDf = pd.read_csv("./RBAM-dataset-2.csv", index_col=0)
count = mergedDf.groupby(["datasetSource", "relation"]).count()
count = mergedDf.groupby(["datasetSource", "relation"]).count()
count = count.rename(columns={"topic": "count"})
count = count.drop(columns=["argSrc", "argTrg"])
count
# Out:
#                                   count
# datasetSource           relation
# arg-microtexts          attack      116
#                         neither    2000
#                         support     190
# argGpt                  attack      471
#                         neither   53197
#                         support    1681
# kialo                   attack    55530
#                         support   54270
# political-argumentation attack      253
#                         neither    1173
#                         support     229

# %%
count.plot(kind='bar', color=['tomato','lightblue','greenyellow'])
# Out:
# <Axes: xlabel='datasetSource,relation'>

# %%
mergedDf = pd.read_csv("./RBAM-dataset-2.csv", index_col=0)
count = mergedDf.groupby(["topic"]).count()
count
# Out:
#                                                     relation  argSrc  argTrg  \
# topic
# ['2000']                                                   3       3       3
# ['ADC', 'Bitcoin', 'Anonymity', 'Blockchain', '...       277     277     277
# ['AGI', 'GPT', 'ChatGPT', 'AI', 'GPT-4']                  23      23      23
# ['AI', 'Art']                                             34      34      34
# ['AI', 'ChatGPT', 'Work', 'Productivity']                 86      86      86
# ...                                                      ...     ...     ...
# disarmament                                              311     311     311
# medical care,health care                                 344     344     344
# minimum wage                                             314     314     314
# unemployment                                             331     331     331
# unknown                                                57655   57655   57655
#
#                                                     datasetSource
# topic
# ['2000']                                                        3
# ['ADC', 'Bitcoin', 'Anonymity', 'Blockchain', '...            277
# ['AGI', 'GPT', 'ChatGPT', 'AI', 'GPT-4']                       23
# ['AI', 'Art']                                                  34
# ['AI', 'ChatGPT', 'Work', 'Productivity']                      86
# ...                                                           ...
# disarmament                                                   311
# medical care,health care                                      344
# minimum wage                                                  314
# unemployment                                                  331
# unknown                                                     57655
#
# [686 rows x 4 columns]
