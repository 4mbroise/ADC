# %%
import pandas as pd

# %%
mergedDf = pd.read_csv("./RBAM-dataset-2.csv", index_col=0)
mergedDf
# Out:
#                                                     topic relation  \
# 108339   ['USA', 'Israel', 'UN', 'Politics', 'Palestine']   attack
# 65903             ['War', 'Middleeast', 'Israel', 'Gaza']   attack
# 27493   ['ChatGPT', 'AI', 'Tech', 'ArtificialIntellige...   attack
# 117654  ['Ethics', 'Sex', 'Medicine', 'Children', 'Hea...   attack
# 48467           ['Education', 'School', 'USA', 'America']   attack
# ...                                                   ...      ...
# 23691        ['God', 'Religion', 'Christianity', 'Faith']  support
# 336     ['Purity', 'Sex', 'Virginity', 'Feminism', 'Wo...  support
# 157432    ['Environment', 'ClimateChange', 'Taxes', 'EU']  support
# 101980  ['USA', 'Trump', 'Government', 'Politics', 'So...  support
# 147595  ['Politics', 'Elections', 'Democracy', 'Societ...  support
#
#                                                    argSrc  \
# 108339  Decoupling [79] the Israeli-Palestine conflict...
# 65903   Many of the conflicts that Israel has engaged ...
# 27493   ChatGPT has shown limitations [171] in handlin...
# 117654  Not getting a vaccine doesn't guarantee that p...
# 48467                                         -> See 1.2.
# ...                                                   ...
# 23691   If Hell is the state of being separated from G...
# 336     Men who make purity pledges continue to view s...
# 157432  This reduction is precisely the required amoun...
# 101980  President Trump called COVID-19 the "Chinese v...
# 147595  Like influencers, people who choose a topic an...
#
#                                                    argTrg datasetSource
# 108339  The US should not support the two-state soluti...         kialo
# 65903   Israel has already fought and won [110] multip...         kialo
# 27493   ChatGPT can be used [168] to handle scheduling...         kialo
# 117654  If the vaccine is free, people will have littl...         kialo
# 48467   Free public education is a good economic publi...         kialo
# ...                                                   ...           ...
# 23691   Going to hell is a decision made by humans, no...         kialo
# 336     Men who make virginity pledges struggle [226] ...         kialo
# 157432  According to research, carbon emissions [241] ...         kialo
# 101980  Much of the freedom President Trump advocated ...         kialo
# 147595  Liquid Democracy may decrease the exploitation...         kialo
#
# [169110 rows x 5 columns]

# %% [markdown]
# # By relation

# %%
count = mergedDf.groupby('relation').count()
count["count"] = count["argSrc"]
count = count.drop(columns=["argSrc", "argTrg", "topic", "datasetSource"])

count
# Out:
#           count
# relation
# attack    56370
# neither   56370
# support   56370

# %%
count.T
# Out:
# relation  attack  neither  support
# count      56370    56370    56370

# %%
count.T.plot(kind='bar', color=['tomato','lightblue','greenyellow'])
# Out:
# <Axes: >

# %%
count.T.plot(kind='bar', color=['tomato','lightblue','greenyellow'], stacked=True)
# Out:
# <Axes: >

# %% [markdown]
# ## By source

# %%
mergedDf = pd.read_csv("./RBAM-dataset-2.csv", index_col=0)
count = mergedDf.groupby('datasetSource').count()
count["count"] = count["argSrc"]
count = count.drop(columns=["topic", "relation", "argSrc", "argTrg"])
count
# Out:
#                           count
# datasetSource
# arg-microtexts             2306
# argGpt                    55349
# kialo                    109800
# political-argumentation    1655

# %%
count.T.plot(kind='bar', color=['tomato','lightblue','greenyellow'])
# Out:
# <Axes: >

# %%
count.T.plot(kind='bar', color=['tomato','lightblue','greenyellow'], stacked=True)
# Out:
# <Axes: >

# %%
mergedDf = pd.read_csv("./RBAM-dataset-2.csv", index_col=0)
count = mergedDf.groupby(["datasetSource", "relation"]).count()
count = mergedDf.groupby(["datasetSource", "relation"]).count()
count = count.rename(columns={"topic": "count"})
count = count.drop(columns=["argSrc", "argTrg"])
count
# Out:
#                                   count
# datasetSource           relation
# arg-microtexts          attack      116
#                         neither    2000
#                         support     190
# argGpt                  attack      471
#                         neither   53197
#                         support    1681
# kialo                   attack    55530
#                         support   54270
# political-argumentation attack      253
#                         neither    1173
#                         support     229

# %%
count.plot(kind='bar', color=['tomato','lightblue','greenyellow'])
# Out:
# <Axes: xlabel='datasetSource,relation'>

# %%
mergedDf = pd.read_csv("./RBAM-dataset-2.csv", index_col=0)
count = mergedDf.groupby(["topic"]).count()
count
# Out:
#                                                     relation  argSrc  argTrg  \
# topic
# ['2000']                                                   3       3       3
# ['ADC', 'Bitcoin', 'Anonymity', 'Blockchain', '...       277     277     277
# ['AGI', 'GPT', 'ChatGPT', 'AI', 'GPT-4']                  23      23      23
# ['AI', 'Art']                                             34      34      34
# ['AI', 'ChatGPT', 'Work', 'Productivity']                 86      86      86
# ...                                                      ...     ...     ...
# disarmament                                              311     311     311
# medical care,health care                                 344     344     344
# minimum wage                                             314     314     314
# unemployment                                             331     331     331
# unknown                                                57655   57655   57655
#
#                                                     datasetSource
# topic
# ['2000']                                                        3
# ['ADC', 'Bitcoin', 'Anonymity', 'Blockchain', '...            277
# ['AGI', 'GPT', 'ChatGPT', 'AI', 'GPT-4']                       23
# ['AI', 'Art']                                                  34
# ['AI', 'ChatGPT', 'Work', 'Productivity']                      86
# ...                                                           ...
# disarmament                                                   311
# medical care,health care                                      344
# minimum wage                                                  314
# unemployment                                                  331
# unknown                                                     57655
#
# [686 rows x 4 columns]
