# %%
import pandas as pd
import numpy as np

# %%
politicalArg = pd.read_csv("../../rawData/political-argumentation/full_dataset.tsv", sep="\t")
politicalArg = politicalArg.rename(columns=
  {
    "argument1": "argSrc",
    "argument2": "argTrg"
  })

politicalArg = politicalArg.drop(columns=["pair_id", "source_arg_1", "source_arg_2"])

politicalArg['datasetSource'] = "political-argumentation"
politicalArg = politicalArg.replace("no_relation", "neither")
politicalArg.head(5)
# Out:
#   topic relation                                             argSrc  \
# 0  cuba  neither  But what I do suggest is that at least we have...
# 1  cuba  neither  What I have advocated is that we use all avail...
# 2  cuba  support  We could have tried to inject ourselves into t...
# 3  cuba  support  And the young men and women , those who are st...
# 4  cuba   attack  I say in that connection that with all the cri...
#
#                                               argTrg            datasetSource
# 0  Too often in these discussions of foreign affa...  political-argumentation
# 1  They can say we ca n't object to the Soviet Un...  political-argumentation
# 2  I do n't take the views that the only alternat...  political-argumentation
# 3  Oh , the problems are great . In Cuba , in the...  political-argumentation
# 4  Major policy on issues such as Cuban security ...  political-argumentation

# %%
argGpt = pd.read_csv("../../rawData/ArGPT/Data/Data V2/argument_relations.csv", index_col=0)
argGpt = argGpt.rename(columns=
  {
    "source_tokens": "argSrc",
    "target_tokens": "argTrg",
    "labels" : "relation"
  })
argGpt = argGpt.drop(columns=["text_id", "source_id", "target_id", "split"])
argGpt['datasetSource'] = "argGpt"
argGpt['topic'] = "unknown"
argGpt = argGpt.replace(np.nan, "neither")
argGpt.head(5)
# Out:
#                                               argSrc  \
# 0  The Romantic movement that emerged in the earl...
# 1  The Romantic movement that emerged in the earl...
# 2  The Romantic movement that emerged in the earl...
# 3  The Romantic movement that emerged in the earl...
# 4  The Romantic movement that emerged in the earl...
#
#                                               argTrg relation datasetSource  \
# 0  The Romantic movement that emerged in the earl...  neither        argGpt
# 1  This movement was characterized by a renewed i...  neither        argGpt
# 2  These themes were a stark contrast to the prev...  neither        argGpt
# 3  The War of a Hundred Years, which lasted from ...  neither        argGpt
# 4  The war was fought between England and France,...  neither        argGpt
#
#      topic
# 0  unknown
# 1  unknown
# 2  unknown
# 3  unknown
# 4  unknown

# %%
argMicrotext = pd.read_csv("../../processedData/arg-microtexts-2-RBAM/data/mergedCorpusRelations.csv", index_col=0)
argMicrotext = argMicrotext.rename(columns=
  {
    "relationType": "relation",
  })
argMicrotext['datasetSource'] = "arg-microtexts"
argMicrotext['topic'] = "unknown"
argMicrotext.head(5)
# Out:
#   relation                                             argSrc  \
# 0  support  For years there has been a housing shortage in...
# 1  neither  For years there has been a housing shortage in...
# 2  neither  For years there has been a housing shortage in...
# 3  neither  For years there has been a housing shortage in...
# 4  neither  For years there has been a housing shortage in...
#
#                                               argTrg   datasetSource    topic
# 0  so that using Tempelhofer Feld, which offers a...  arg-microtexts  unknown
# 1  Since the area belongs to the federal state, o...  arg-microtexts  unknown
# 2  it could even be used for social housing with ...  arg-microtexts  unknown
# 3  Admittedly the fields have currently become an...  arg-microtexts  unknown
# 4  If however one could find a compromise between...  arg-microtexts  unknown

# %%
kialo = pd.read_csv("../../processedData/kialo-2-RBAM/kialoPairs.csv", index_col=0)
kialo.head(5)
# Out:
#                                                topic relation  \
# 0  ['Purity', 'Sex', 'Virginity', 'Feminism', 'Wo...  support
# 1  ['Purity', 'Sex', 'Virginity', 'Feminism', 'Wo...  support
# 2  ['Purity', 'Sex', 'Virginity', 'Feminism', 'Wo...  support
# 3  ['Purity', 'Sex', 'Virginity', 'Feminism', 'Wo...  support
# 4  ['Purity', 'Sex', 'Virginity', 'Feminism', 'Wo...  support
#
#                                               argSrc  \
# 0  Purity pledges lead to people not having a pro...
# 1  Purity pledges are a facet of abstinence-only ...
# 2  Abstinence programmes are likely to lead to pe...
# 3  Pledgers often believe contraceptives are unre...
# 4  Abstinence programmes push against [3] increas...
#
#                                               argTrg datasetSource
# 0  Purity pledges lead to people having a poorer ...         kialo
# 1  Purity pledges lead to people not having a pro...         kialo
# 2  Purity pledges are a facet of abstinence-only ...         kialo
# 3  Abstinence programmes are likely to lead to pe...         kialo
# 4  Abstinence programmes are likely to lead to pe...         kialo

# %%
RBAMdataset = pd.concat([politicalArg, argGpt, argMicrotext, kialo])

# %%
RBAMdataset
# Out:
#         topic relation                                             argSrc  \
# 0        cuba  neither  But what I do suggest is that at least we have...
# 1        cuba  neither  What I have advocated is that we use all avail...
# 2        cuba  support  We could have tried to inject ourselves into t...
# 3        cuba  support  And the young men and women , those who are st...
# 4        cuba   attack  I say in that connection that with all the cri...
# ...       ...      ...                                                ...
# 2459  unknown  neither  but that people with the same income suddenly ...
# 2460  unknown  support  Gentrification destroys entire districts and t...
# 2461  unknown  neither  Gentrification destroys entire districts and t...
# 2462  unknown  neither  Gentrification destroys entire districts and t...
# 2463  unknown  neither  Gentrification destroys entire districts and t...
#
#                                                  argTrg  \
# 0     Too often in these discussions of foreign affa...
# 1     They can say we ca n't object to the Soviet Un...
# 2     I do n't take the views that the only alternat...
# 3     Oh , the problems are great . In Cuba , in the...
# 4     Major policy on issues such as Cuban security ...
# ...                                                 ...
# 2459  Gentrification destroys entire districts and t...
# 2460  Rent prices should be limited by a cap when th...
# 2461    Landlords may want to earn as much as possible,
# 2462  and many, consistent with market principles, a...
# 2463  but that people with the same income suddenly ...
#
#                 datasetSource
# 0     political-argumentation
# 1     political-argumentation
# 2     political-argumentation
# 3     political-argumentation
# 4     political-argumentation
# ...                       ...
# 2459           arg-microtexts
# 2460           arg-microtexts
# 2461           arg-microtexts
# 2462           arg-microtexts
# 2463           arg-microtexts
#
# [60823 rows x 5 columns]

# %%
RBAMdataset.to_csv("RBAM-dataset-2.csv")
