# %%
import pandas as pd

# %%
balancedDataset = pd.read_csv("./full_dataset.tsv" ,sep='\t', index_col=0)
balancedDataset
# Out:
#                 topic     relation  \
# pair_id
# 1                cuba  no_relation
# 2                cuba  no_relation
# 3                cuba      support
# 4                cuba      support
# 5                cuba       attack
# ...               ...          ...
# 1903             cuba  no_relation
# 1904     minimum wage  no_relation
# 1905     minimum wage  no_relation
# 1906      disarmament  no_relation
# 1907      disarmament      support
#
#                                                  argument1  \
# pair_id
# 1        But what I do suggest is that at least we have...
# 2        What I have advocated is that we use all avail...
# 3        We could have tried to inject ourselves into t...
# 4        And the young men and women , those who are st...
# 5        I say in that connection that with all the cri...
# ...                                                    ...
# 1903     I do not know how he can seek the Presidency a...
# 1904     You have the Kennedy bill , which would raise ...
# 1905     But these rivers in the New York area are not ...
# 1906     Well , let me say that in the first place I th...
# 1907     I know that you must never make a concession t...
#
#                                                  argument2  \
# pair_id
# 1        Too often in these discussions of foreign affa...
# 2        They can say we ca n't object to the Soviet Un...
# 3        I do n't take the views that the only alternat...
# 4        Oh , the problems are great . In Cuba , in the...
# 5        Major policy on issues such as Cuban security ...
# ...                                                    ...
# 1903     These are the times that you can read and have...
# 1904     To pass them by - to water down the help they ...
# 1905     I think , as you are aware , you actually have...
# 1906     I 'm confident of what America can do in the y...
# 1907     But no matter how difficult the problems are ,...
#
#                       source_arg_1              source_arg_2
# pair_id
# 1          Kennedy_October_23_1960     Nixon_October_22_1960
# 2          Kennedy_October_23_1960     Nixon_October_22_1960
# 3          Nixon_September_12_1960  Kennedy_September_2_1960
# 4         Kennedy_September_2_1960      Nixon_August_26_1960
# 5             Nixon_October_6_1960    Kennedy_October_6_1960
# ...                            ...                       ...
# 1903       Kennedy_October_15_1960     Nixon_October_14_1960
# 1904          Nixon_August_13_1960    Kennedy_August_10_1960
# 1905     Kennedy_September_29_1960      Nixon_August_13_1960
# 1906     Kennedy_September_17_1960   Nixon_September_12_1960
# 1907         Nixon_October_25_1960   Kennedy_October_23_1960
#
# [1907 rows x 6 columns]

# %%
bySubject = balancedDataset.groupby(["topic", "relation"]).count()
bySubject["count"] = bySubject["argument1"]
bySubject = bySubject.drop(columns=["argument1", "argument2", "source_arg_1", "source_arg_2"])
bySubject
# Out:
#                                       count
# topic                    relation
# cuba                     attack          38
#                          no_relation    302
#                          support         40
# disarmament              attack          76
#                          no_relation    192
#                          support        108
# medical care,health care attack          75
#                          no_relation    235
#                          support         72
# minimum wage             attack         125
#                          no_relation    180
#                          support         83
# unemployment             attack          64
#                          no_relation    264
#                          support         53

# %%
bySubject
# Out:
#                                       count
# topic                    relation
# cuba                     attack          38
#                          no_relation    302
#                          support         40
# disarmament              attack          76
#                          no_relation    192
#                          support        108
# medical care,health care attack          75
#                          no_relation    235
#                          support         72
# minimum wage             attack         125
#                          no_relation    180
#                          support         83
# unemployment             attack          64
#                          no_relation    264
#                          support         53

# %%
bySubject.plot(kind="bar"),
# Out:
# (<Axes: xlabel='topic,relation'>,)

# %%
bySubject = bySubject.reset_index()
bySubject
bySubject.index = bySubject.topic 
bySubject= bySubject.drop(columns="topic")
bySubject
# Out:
#                              relation  count
# topic
# cuba                           attack     38
# cuba                      no_relation    302
# cuba                          support     40
# disarmament                    attack     76
# disarmament               no_relation    192
# disarmament                   support    108
# medical care,health care       attack     75
# medical care,health care  no_relation    235
# medical care,health care      support     72
# minimum wage                   attack    125
# minimum wage              no_relation    180
# minimum wage                  support     83
# unemployment                   attack     64
# unemployment              no_relation    264
# unemployment                  support     53

# %%
bySubject = bySubject.pivot_table('count', ['topic'], 'relation')
bySubject
# Out:
# relation                  attack  no_relation  support
# topic
# cuba                        38.0        302.0     40.0
# disarmament                 76.0        192.0    108.0
# medical care,health care    75.0        235.0     72.0
# minimum wage               125.0        180.0     83.0
# unemployment                64.0        264.0     53.0

# %%
bySubject.plot.bar(color=['tomato','lightblue','greenyellow'])
# Out:
# <Axes: xlabel='topic'>

# %%
bySubject.plot.bar(color=['tomato','lightblue','greenyellow'], stacked=True)
# Out:
# <Axes: xlabel='topic'>
